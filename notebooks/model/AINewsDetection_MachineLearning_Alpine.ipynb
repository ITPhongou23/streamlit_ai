# %% [markdown]
# ## Hệ Thống Phát Hiện Văn Bản AI (OOD-Robust AI Detection Pipeline)
#
# Notebook này xây dựng một hệ thống phát hiện văn bản do AI tạo ra với khả năng **thích ứng ngoại miền (OOD-Robust)**, tập trung vào tiếng Việt. Hệ thống được thiết kế để giải quyết sự khác biệt về phân phối dữ liệu giữa tập huấn luyện và thực tế.
#
# ### 1. Mục Tiêu Chính
# *   Xây dựng Pipeline trích xuất đặc trưng đa tầng: Logic, Ngữ pháp, Ngữ nghĩa và Động lực học (Surprisal).
# *   Huấn luyện mô hình **XGBoost** kết hợp kỹ thuật **Adversarial Validation** để gán trọng số cho dữ liệu huấn luyện giống với dữ liệu thực tế (OOD).
# *   Tối ưu hóa ngưỡng phân loại (Threshold) dựa trên F2-Score để ưu tiên khả năng bắt được AI (Recall) trong khi vẫn giữ độ chính xác (Precision) trên 70%.
#
# ### 2. Các Nhóm Đặc Trưng (Features)
# *   **Causal Surprisal (GPT-Neo):** Đo lường độ bất ngờ của từ ngữ dựa trên mô hình ngôn ngữ lớn.
# *   **Advanced Logic:** Sử dụng N-gram và Regex để phân tích mật độ các từ nối logic (Causal, Contrast, Additive, Temporal).
# *   **Semantic Drift (PhoBERT):** Phân tích sự mạch lạc và độ trôi dạt ngữ nghĩa giữa các câu bằng Sentence Embeddings.
# *   **Syntactic & Structural:** Các chỉ số về độ biến thiên độ dài câu, mật độ dấu câu và đại từ.
#
# ### 3. Quy Trình Kỹ Thuật
# 1.  **Adversarial Weighting:** Tính toán mức độ khác biệt giữa tập ID (Trong miền) và OOD (Ngoài miền) để điều chỉnh mô hình.
# 2.  **Calibration:** Hiệu chuẩn xác suất đầu ra (Sigmoid/Isotonic) để phản ánh đúng độ tin cậy.
# 3.  **Bootstrapping Threshold:** Quét tìm ngưỡng tối ưu ổn định qua nhiều vòng xáo trộn dữ liệu.
#
# ### 4. Sản Phẩm Đầu Ra (Artifacts)
# *   `xgb_robust_final.joblib`: File model đã huấn luyện.
# *   `model_config.json`: Chứa danh sách features và ngưỡng threshold tối ưu.
# *   `logic_markers_prod.json`: Danh sách các N-gram logic đã học được từ quá trình EDA.
# *   **Hugging Face Hub:** Tự động đẩy các artifacts lên repo để phục vụ triển khai (Streamlit/API).

# %%
# !pip install numpy pandas scikit-learn huggingface_hub xgboost transformers scipy torch shap betacal underthesea tqdm joblib ipython dotenv -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 71.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 64.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 52.1 MB/s eta 0:00:00

# %%
import gc
import json
import os
import re
import string
import unicodedata
import warnings
from collections import Counter

import joblib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import shap
import torch
import xgboost as xgb
from huggingface_hub import login, HfApi
from dotenv import find_dotenv, load_dotenv
from IPython.display import display
from scipy.stats import entropy
from sklearn.calibration import CalibratedClassifierCV, CalibrationDisplay
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.inspection import permutation_importance
from sklearn.metrics import (
    accuracy_score,
    brier_score_loss,
    classification_report,
    confusion_matrix,
    f1_score,
    fbeta_score,
    precision_recall_curve,
    precision_score,
    recall_score,
    roc_auc_score,
)
from sklearn.model_selection import (
    GroupKFold,
    train_test_split,
)
from sklearn.pipeline import Pipeline
from tqdm import tqdm
from transformers import (
    AutoModel,
    AutoModelForCausalLM,
    AutoTokenizer,
)
from transformers import logging as transformers_logging
from underthesea import ner, pos_tag, sent_tokenize, word_tokenize
from xgboost import XGBClassifier

warnings.filterwarnings("ignore")
transformers_logging.set_verbosity_error()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root_path = "/content/drive/MyDrive/BTL_AI_13_IT2302/AIWritingIndicator-13/SourceCode/"
# %cd {root_path}
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/17JBaRqvfDFY0j8cN0vwu8kzqwtDISdDR/BTL_AI_13_IT2302/AIWritingIndicator-13/SourceCode
# /content/drive/.shortcut-targets-by-id/17JBaRqvfDFY0j8cN0vwu8kzqwtDISdDR/BTL_AI_13_IT2302/AIWritingIndicator-13/SourceCode

# %%
env_path = find_dotenv()

if env_path:
    load_dotenv(env_path)
else:
    print("Không tìm thấy file .env!")

# %%
hf_token = os.getenv("HF_TOKEN")

if hf_token:
    login()
else:
    print("Không tồn tại env HF_TOKEN!")

# %%
class OODRobustAIDetectionPipeline:
    def __init__(self, train_path, ood_path, artifact_dir="Model_Artifacts"):
        self.train_path = train_path
        self.ood_path = ood_path
        self.artifact_dir = artifact_dir

        os.makedirs(self.artifact_dir, exist_ok=True)

        self.features = []
        self.model = None
        self.optimal_threshold_ood = 0.5
        self.weights = None

        self.X_train_core = self.y_train_core = None
        self.X_id_test = self.y_id_test = None
        self.X_ood_val = self.y_ood_val = None
        self.X_ood_test = self.y_ood_test = None

    def load_and_prepare_data(self):
        print("1. Đang tải và chuẩn bị dữ liệu...")
        df_train = pd.read_csv(self.train_path)
        df_ood = pd.read_csv(self.ood_path)

        exclude_cols = ['label', 'text', 'id', 'origin', 'domain']
        self.features = [c for c in df_train.columns if c not in exclude_cols and pd.api.types.is_numeric_dtype(df_train[c])]

        print(f" -> Đã nhận diện {len(self.features)} numeric features.")

        self.X_train_core, self.X_id_test, self.y_train_core, self.y_id_test = train_test_split(
            df_train[self.features], df_train['label'],
            test_size=0.2, random_state=42, stratify=df_train['label']
        )

        self.X_ood_val, self.X_ood_test, self.y_ood_val, self.y_ood_test = train_test_split(
            df_ood[self.features], df_ood['label'],
            test_size=0.5, random_state=42, stratify=df_ood['label']
        )

    def calculate_sample_weights(self):
        print("2. Đang tính toán Importance Weights (Adversarial Validation)...")
        X_adv = pd.concat([self.X_train_core, self.X_ood_val], ignore_index=True)
        y_adv = np.array([0] * len(self.X_train_core) + [1] * len(self.X_ood_val))

        clf_adv_base = xgb.XGBClassifier(n_estimators=100, max_depth=3, learning_rate=0.1, random_state=42, n_jobs=-1)

        clf_adv = CalibratedClassifierCV(estimator=clf_adv_base, method='sigmoid', cv=5)
        clf_adv.fit(X_adv, y_adv)

        probs_adv_all = clf_adv.predict_proba(X_adv)[:, 1]
        auc_adv = roc_auc_score(y_adv, probs_adv_all)
        print(f" -> Adversarial AUC (Drift Score): {auc_adv:.4f}")

        if auc_adv <= 0.55:
            print(" -> [THÔNG BÁO] Phân phối ID và OOD gần như đồng nhất (AUC ~ 0.5). Gán uniform weights = 1.0.")
            self.weights = np.ones(len(self.X_train_core))
        else:
            p_ood = clf_adv.predict_proba(self.X_train_core)[:, 1]
            p_ood = np.clip(p_ood, 1e-5, 1 - 1e-5)

            logits = np.log(p_ood / (1 - p_ood))
            w_raw = np.exp(logits)

            lower_bound, upper_bound = 0.2, 3.0
            mid_point = (lower_bound + upper_bound) / 2.0

            self.weights = lower_bound + (upper_bound - lower_bound) * (1 / (1 + np.exp(-(w_raw - mid_point))))

        print(f" -> Mean weight cuối: {self.weights.mean():.3f}, Min: {self.weights.min():.3f}, Max: {self.weights.max():.3f}")

        plt.figure(figsize=(8, 5))
        plt.hist(self.weights, bins=50, color='teal', edgecolor='black', alpha=0.7)
        plt.title("Phân bố Adversarial Weights (Soft Clipped)")
        plt.xlabel("Weight Value")
        plt.ylabel("Frequency")
        plt.grid(True, linestyle='--', alpha=0.5)
        plt.show()

    def _optimize_threshold(self, y_true, y_probs):
        print("\n--- THRESHOLD SCANNING LOG (OOD Thực tế) ---")

        brier = brier_score_loss(y_true, y_probs)
        print(f" -> Brier Score của Probabilities: {brier:.4f}")
        print("--------------------------------------------------")

        test_mocs = np.arange(0.02, 0.51, 0.02)
        for t in test_mocs:
            preds = (y_probs >= t).astype(int)
            rec = recall_score(y_true, preds, zero_division=0)
            prec = precision_score(y_true, preds, zero_division=0)
            f1 = f1_score(y_true, preds, zero_division=0)
            f2 = fbeta_score(y_true, preds, beta=2, zero_division=0)
            print(f" * Threshold = {t:.2f} | Recall = {rec:.4f} | Precision = {prec:.4f} | F1 = {f1:.4f} | F2 = {f2:.4f}")

        print("--------------------------------------------------")

        n_bootstraps = 50
        optimal_thresholds = []
        thresholds = np.arange(0.02, 0.51, 0.02)

        print(f" -> Đang chạy Bootstrapping ({n_bootstraps} vòng) để tìm ngưỡng Tối ưu (F2 cao nhất & Precision >= 0.7)...")

        for i in range(n_bootstraps):
            indices = np.random.choice(len(y_true), size=len(y_true), replace=True)

            if isinstance(y_true, (pd.Series, pd.DataFrame)):
                y_true_boot = y_true.iloc[indices].values
            else:
                y_true_boot = y_true[indices]

            y_probs_boot = y_probs[indices]

            best_f2 = 0
            best_t = 0.5

            for t in thresholds:
                preds = (y_probs_boot >= t).astype(int)
                prec = precision_score(y_true_boot, preds, zero_division=0)
                f2 = fbeta_score(y_true_boot, preds, beta=2, zero_division=0)

                if prec >= 0.7 and f2 > best_f2:
                    best_f2, best_t = f2, t

            if best_f2 == 0:
                for t in thresholds:
                    preds = (y_probs_boot >= t).astype(int)
                    f2 = fbeta_score(y_true_boot, preds, beta=2, zero_division=0)
                    if f2 > best_f2:
                        best_f2, best_t = f2, t

            optimal_thresholds.append(best_t)

        final_threshold = np.median(optimal_thresholds)

        final_preds = (y_probs >= final_threshold).astype(int)
        f_rec = recall_score(y_true, final_preds, zero_division=0)
        f_prec = precision_score(y_true, final_preds, zero_division=0)
        f_f1 = f1_score(y_true, final_preds, zero_division=0)
        f_f2 = fbeta_score(y_true, final_preds, beta=2, zero_division=0)

        print(f" -> Ngưỡng (Threshold) Tối ưu Median: {final_threshold:.2f}")
        print(f" -> Hiệu năng tại ngưỡng {final_threshold:.2f}:")
        print(f"    * Recall    : {f_rec:.4f}")
        print(f"    * Precision : {f_prec:.4f} (Mục tiêu >= 0.7)")
        print(f"    * F1-Score  : {f_f1:.4f}")
        print(f"    * F2-Score  : {f_f2:.4f} (Thang đo tối ưu chính)")

        if f_prec < 0.7:
             print("    [CẢNH BÁO] Hệ thống không tìm được ngưỡng nào thỏa mãn Precision >= 0.7, đã tự động Fallback về ngưỡng tối ưu F2 tốt nhất có thể.")

        return final_threshold

    def _calculate_ece(self, y_true, y_prob, n_bins=10):
        bin_limits = np.linspace(0, 1, n_bins + 1)
        bin_lowers = bin_limits[:-1]
        bin_uppers = bin_limits[1:]

        ece = 0.0
        for lower, upper in zip(bin_lowers, bin_uppers):
            in_bin = (y_prob > lower) & (y_prob <= upper)
            if lower == 0.0:
                in_bin = (y_prob >= lower) & (y_prob <= upper)

            prop_in_bin = in_bin.mean()
            if prop_in_bin > 0:
                accuracy_in_bin = y_true[in_bin].mean()
                avg_confidence_in_bin = y_prob[in_bin].mean()
                ece += np.abs(avg_confidence_in_bin - accuracy_in_bin) * prop_in_bin
        return ece

    def _select_best_calibration(self, base_model, iso_model, sig_model):
        probs_base = base_model.predict_proba(self.X_ood_val)[:, 1]
        probs_iso = iso_model.predict_proba(self.X_ood_val)[:, 1]
        probs_sig = sig_model.predict_proba(self.X_ood_val)[:, 1]

        brier_base = brier_score_loss(self.y_ood_val, probs_base)
        brier_iso = brier_score_loss(self.y_ood_val, probs_iso)
        brier_sig = brier_score_loss(self.y_ood_val, probs_sig)

        ece_base = self._calculate_ece(self.y_ood_val, probs_base)
        ece_iso = self._calculate_ece(self.y_ood_val, probs_iso)
        ece_sig = self._calculate_ece(self.y_ood_val, probs_sig)

        auc_base = roc_auc_score(self.y_ood_val, probs_base)
        auc_iso = roc_auc_score(self.y_ood_val, probs_iso)
        auc_sig = roc_auc_score(self.y_ood_val, probs_sig)

        print("\n--- CALIBRATION EVALUATION (OOD_Val) ---")
        print(f" * BASE     | Brier: {brier_base:.4f} | ECE: {ece_base:.4f} | AUC: {auc_base:.4f}")
        print(f" * SIGMOID  | Brier: {brier_sig:.4f}  | ECE: {ece_sig:.4f}  | AUC: {auc_sig:.4f}")
        print(f" * ISOTONIC | Brier: {brier_iso:.4f}  | ECE: {ece_iso:.4f}  | AUC: {auc_iso:.4f}")

        fig, ax = plt.subplots(figsize=(8, 8))
        CalibrationDisplay.from_predictions(self.y_ood_val, probs_base, n_bins=10, name="Base XGBoost", ax=ax, strategy='quantile')
        CalibrationDisplay.from_predictions(self.y_ood_val, probs_iso, n_bins=10, name="Isotonic", ax=ax, strategy='quantile')
        CalibrationDisplay.from_predictions(self.y_ood_val, probs_sig, n_bins=10, name="Sigmoid (Platt)", ax=ax, strategy='quantile')
        ax.set_title("Reliability Curve (OOD Validation)")
        ax.grid(True, linestyle='--', alpha=0.7)
        plt.show()

        best_ece = min(ece_base, ece_iso, ece_sig)
        tolerance_ece = ece_base * 0.05

        if (ece_base - best_ece) <= tolerance_ece:
            print(" -> [QUYẾT ĐỊNH] ECE không cải thiện quá 5%. CHỌN BASE XGBOOST (Bảo toàn model gốc).")
            return base_model

        if best_ece == ece_iso:
            if (auc_base - auc_iso) > 0.005:
                print(" -> [CẢNH BÁO ĐỎ] Isotonic có ECE tốt nhưng làm sụt giảm ROC-AUC > 0.005 (Phá hỏng Ranking).")
                print(" -> [QUYẾT ĐỊNH] Fallback về SIGMOID để giữ an toàn.")
                return sig_model
            else:
                print(" -> [QUYẾT ĐỊNH] Isotonic cải thiện ECE vượt trội và an toàn về AUC. CHỌN ISOTONIC.")
                return iso_model

        print(" -> [QUYẾT ĐỊNH] Sigmoid là phương án cân bằng nhất. CHỌN SIGMOID.")
        return sig_model

    def train_and_calibrate(self):
        print("\n3. Đang huấn luyện XGBoost OOD-Robust...")

        xgb_params = {
            'objective': 'binary:logistic',
            'eval_metric': 'logloss',
            'learning_rate': 0.03,
            'n_estimators': 700,
            'max_depth': 5,
            'min_child_weight': 3,
            'gamma': 2.0,
            'reg_alpha': 2.0,
            'reg_lambda': 5.0,
            'subsample': 0.8,
            'colsample_bytree': 0.6,
            'colsample_bynode': 0.6,
            'max_delta_step': 1,
            'tree_method': 'hist',
            'random_state': 42,
            'n_jobs': -1
        }

        print(" -> [FEATURE SELECTION] Đang chạy pre-training để đo tầm quan trọng của features...")
        pre_model = xgb.XGBClassifier(**xgb_params)
        pre_model.fit(self.X_train_core, self.y_train_core, sample_weight=self.weights)

        print(" -> [FEATURE SELECTION] Tính toán Permutation Importance...")
        perm_result = permutation_importance(
            pre_model, self.X_id_test, self.y_id_test,
            scoring='roc_auc', n_repeats=5, random_state=42, n_jobs=-1
        )

        selected_features = []
        threshold = np.percentile(perm_result.importances_mean, 25)
        for i, f in enumerate(self.features):
            if perm_result.importances_mean[i] > threshold:
                selected_features.append(f)

        if len(selected_features) == 0:
            print(" -> [CẢNH BÁO] Không có feature nào vượt ngưỡng importance. Giữ lại toàn bộ để fallback.")
            selected_features = self.features

        print(f" -> [FEATURE SELECTION] Đã giữ lại {len(selected_features)}/{len(self.features)} features thực sự mạnh (Importance > {threshold:.4f}).")

        self.features = selected_features

        print(" -> [FEATURE SELECTION] Đang kiểm tra tương quan giữa các features...")
        corr_matrix = self.X_train_core[self.features].corr().abs()
        upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

        to_drop = [column for column in upper.columns if any(upper[column] > 0.9)]

        if len(to_drop) > 0:
            self.features = [f for f in self.features if f not in to_drop]
            print(f" -> [FEATURE SELECTION] Đã loại bỏ {len(to_drop)} features do tương quan quá cao (>0.9). Còn lại {len(self.features)} features.")

        self.X_train_core = self.X_train_core[self.features]
        self.X_id_test = self.X_id_test[self.features]
        self.X_ood_val = self.X_ood_val[self.features]
        self.X_ood_test = self.X_ood_test[self.features]

        print(" -> Đang huấn luyện mô hình chính thức với các features đã chọn...")
        base_model = xgb.XGBClassifier(**xgb_params)
        base_model.fit(self.X_train_core, self.y_train_core, sample_weight=self.weights)

        iso_model = CalibratedClassifierCV(estimator=base_model, method='isotonic', cv='prefit')
        iso_model.fit(self.X_train_core, self.y_train_core)

        sig_model = CalibratedClassifierCV(estimator=base_model, method='sigmoid', cv='prefit')
        sig_model.fit(self.X_train_core, self.y_train_core)

        self.model = self._select_best_calibration(base_model, iso_model, sig_model)

        print("\n4. Đang tối ưu Threshold trên OOD Validation...")
        probs_ood_val = self.model.predict_proba(self.X_ood_val)[:, 1]
        self.optimal_threshold_ood = self._optimize_threshold(self.y_ood_val, probs_ood_val)
        print(f" -> Threshold Chốt Cuối Cùng: {self.optimal_threshold_ood:.3f}")

        self.plot_decision_curves(self.X_ood_val, self.y_ood_val, "OOD_Validation")

    def plot_decision_curves(self, X, y, dataset_name):
        probs = self.model.predict_proba(X)[:, 1]
        precisions, recalls, thresholds = precision_recall_curve(y, probs)

        fig, axes = plt.subplots(1, 2, figsize=(14, 6))

        axes[0].plot(recalls, precisions, color='purple', lw=2)
        axes[0].set_xlabel("Recall (AI Detection Rate)")
        axes[0].set_ylabel("Precision")
        axes[0].set_title(f"Precision-Recall Curve ({dataset_name})")
        axes[0].grid(True, linestyle='--', alpha=0.6)

        axes[1].plot(thresholds, precisions[:-1], 'b--', label='Precision', lw=2)
        axes[1].plot(thresholds, recalls[:-1], 'g-', label='Recall', lw=2)
        axes[1].axvline(x=self.optimal_threshold_ood, color='red', linestyle='-', lw=2, label=f'Chosen Thresh ({self.optimal_threshold_ood:.2f})')
        axes[1].set_xlabel("Decision Threshold")
        axes[1].set_ylabel("Score")
        axes[1].set_title(f"Threshold Trade-off ({dataset_name})")
        axes[1].legend(loc="lower left")
        axes[1].grid(True, linestyle='--', alpha=0.6)

        plt.tight_layout()
        plt.show()

    def evaluate_model(self, X, y, dataset_name=""):
        print(f"\n--- ĐÁNH GIÁ TRÊN TẬP: {dataset_name} ---")
        probs = self.model.predict_proba(X)[:, 1]
        preds = (probs >= self.optimal_threshold_ood).astype(int)

        auc = roc_auc_score(y, probs)
        f1 = f1_score(y, preds)
        prec = precision_score(y, preds)
        rec = recall_score(y, preds)

        print(f"AUC: {auc:.4f} | F1: {f1:.4f} | Precision: {prec:.4f} | Recall: {rec:.4f}")
        print(classification_report(y, preds))

        return {"AUC": auc, "F1": f1, "Precision": prec, "Recall": rec}

    def run_sanity_checks(self):
        print("\n5. Đang chạy Sanity Checks (Trên tập OOD Test mù)...")
        result = permutation_importance(
            self.model, self.X_ood_test, self.y_ood_test,
            scoring='roc_auc', n_repeats=5, random_state=42, n_jobs=-1
        )

        importance_df = pd.DataFrame({
            'Feature': self.features,
            'Importance': result.importances_mean
        }).sort_values(by='Importance', ascending=False)

        top_f = importance_df.iloc[0]
        print(f"    * Feature mạnh nhất: {top_f['Feature']} (Drop AUC: {top_f['Importance']:.4f})")

        if top_f['Importance'] > 0.25:
            print("    [CẢNH BÁO ĐỎ] Mô hình có rủi ro Collapse (phụ thuộc quá mạnh vào 1 feature).")
        else:
            print("    [AN TOÀN] Không feature nào độc tôn. Mô hình học đặc trưng đa dạng.")

        return importance_df

    def save_artifacts(self, id_metrics, ood_metrics, importance_df):
        print("\n6. Đang lưu Artifacts...")
        joblib.dump(self.model, os.path.join(self.artifact_dir, "xgb_robust_final.joblib"))

        config = {
            "optimal_threshold_ood": float(self.optimal_threshold_ood),
            "features": self.features,
            "metrics_id": id_metrics,
            "metrics_ood": ood_metrics
        }
        with open(os.path.join(self.artifact_dir, "model_config.json"), "w", encoding="utf-8") as f:
            json.dump(config, f, indent=4)

        importance_df.to_csv(os.path.join(self.artifact_dir, "permutation_importance_ood.csv"), index=False)
        print(f" -> Hoàn tất! Artifacts được lưu tại: {self.artifact_dir}/")

    def execute_full_pipeline(self):
        print("=== BẮT ĐẦU PIPELINE XGBOOST OOD-ROBUST ===")
        self.load_and_prepare_data()
        self.calculate_sample_weights()
        self.train_and_calibrate()

        id_metrics = self.evaluate_model(self.X_id_test, self.y_id_test, "IN-DISTRIBUTION TEST (ID)")
        ood_metrics = self.evaluate_model(self.X_ood_test, self.y_ood_test, "OUT-OF-DISTRIBUTION TEST (OOD Mù)")

        importance_df = self.run_sanity_checks()
        self.save_artifacts(id_metrics, ood_metrics, importance_df)

# %%
class HuggingFaceModelPusher:
    def __init__(self, repo_id, artifact_dir="Model_Artifacts"):
        self.repo_id = repo_id
        self.artifact_dir = artifact_dir
        self.api = HfApi()

    def push_to_hub(self, commit_message="Upload XGBoost OOD-Robust model and artifacts"):
        print(f"\n7. Đang đẩy model và artifacts từ thư mục '{self.artifact_dir}' lên Hugging Face Hub ({self.repo_id})...")

        self.api.create_repo(repo_id=self.repo_id, exist_ok=True, repo_type="model")

        self.api.upload_folder(
            folder_path=self.artifact_dir,
            repo_id=self.repo_id,
            repo_type="model",
            commit_message=commit_message
        )

        print(f" -> Hoàn tất đẩy dữ liệu lên Hugging Face! Bạn có thể xem tại: https://huggingface.co/{self.repo_id}")

# %%
pipeline = OODRobustAIDetectionPipeline(
    train_path="Data/Final/iccies_dataset_feature_integration_cleaned_hotfix.csv",
    ood_path="Data/Final/vietnamese_news_ai_dataset_feature_integration_cleaned_hotfix.csv",
    artifact_dir="Artifacts"
)
pipeline.execute_full_pipeline()
# Out:
# === BẮT ĐẦU PIPELINE XGBOOST OOD-ROBUST ===
# 1. Đang tải và chuẩn bị dữ liệu...
#  -> Đã nhận diện 29 numeric features.
# 2. Đang tính toán Importance Weights (Adversarial Validation)...
#  -> Adversarial AUC (Drift Score): 0.9486
#  -> Mean weight cuối: 0.743, Min: 0.682, Max: 3.000
# 3. Đang huấn luyện XGBoost OOD-Robust...
#  -> [FEATURE SELECTION] Đang chạy pre-training để đo tầm quan trọng của features...
#  -> [FEATURE SELECTION] Tính toán Permutation Importance...
#  -> [FEATURE SELECTION] Đã giữ lại 21/29 features thực sự mạnh (Importance > 0.0001).
#  -> [FEATURE SELECTION] Đang kiểm tra tương quan giữa các features...
#  -> [FEATURE SELECTION] Đã loại bỏ 2 features do tương quan quá cao (>0.9). Còn lại 19 features.
#  -> Đang huấn luyện mô hình chính thức với các features đã chọn...
#
# --- CALIBRATION EVALUATION (OOD_Val) ---
#  * BASE     | Brier: 0.2501 | ECE: 0.2579 | AUC: 0.8435
#  * SIGMOID  | Brier: 0.2826  | ECE: 0.2878  | AUC: 0.8435
#  * ISOTONIC | Brier: 0.2694  | ECE: 0.2816  | AUC: 0.8395
#  -> [QUYẾT ĐỊNH] ECE không cải thiện quá 5%. CHỌN BASE XGBOOST (Bảo toàn model gốc).
#
# 4. Đang tối ưu Threshold trên OOD Validation...
#
# --- THRESHOLD SCANNING LOG (OOD Thực tế) ---
#  -> Brier Score của Probabilities: 0.2501
# --------------------------------------------------
#  * Threshold = 0.02 | Recall = 0.9063 | Precision = 0.6549 | F1 = 0.7604 | F2 = 0.8417
#  * Threshold = 0.04 | Recall = 0.8305 | Precision = 0.7120 | F1 = 0.7667 | F2 = 0.8037
#  * Threshold = 0.06 | Recall = 0.7757 | Precision = 0.7488 | F1 = 0.7620 | F2 = 0.7701
#  * Threshold = 0.08 | Recall = 0.7388 | Precision = 0.7743 | F1 = 0.7561 | F2 = 0.7456
#  * Threshold = 0.10 | Recall = 0.7159 | Precision = 0.8013 | F1 = 0.7562 | F2 = 0.7315
#  * Threshold = 0.12 | Recall = 0.6770 | Precision = 0.8151 | F1 = 0.7397 | F2 = 0.7007
#  * Threshold = 0.14 | Recall = 0.6491 | Precision = 0.8304 | F1 = 0.7286 | F2 = 0.6787
#  * Threshold = 0.16 | Recall = 0.6221 | Precision = 0.8421 | F1 = 0.7156 | F2 = 0.6564
#  * Threshold = 0.18 | Recall = 0.6052 | Precision = 0.8549 | F1 = 0.7087 | F2 = 0.6427
#  * Threshold = 0.20 | Recall = 0.5833 | Precision = 0.8680 | F1 = 0.6977 | F2 = 0.6242
#  * Threshold = 0.22 | Recall = 0.5613 | Precision = 0.8715 | F1 = 0.6828 | F2 = 0.6043
#  * Threshold = 0.24 | Recall = 0.5414 | Precision = 0.8744 | F1 = 0.6687 | F2 = 0.5860
#  * Threshold = 0.26 | Recall = 0.5274 | Precision = 0.8787 | F1 = 0.6592 | F2 = 0.5733
#  * Threshold = 0.28 | Recall = 0.5155 | Precision = 0.8838 | F1 = 0.6511 | F2 = 0.5623
#  * Threshold = 0.30 | Recall = 0.5015 | Precision = 0.8903 | F1 = 0.6416 | F2 = 0.5495
#  * Threshold = 0.32 | Recall = 0.4865 | Precision = 0.9004 | F1 = 0.6317 | F2 = 0.5358
#  * Threshold = 0.34 | Recall = 0.4756 | Precision = 0.9051 | F1 = 0.6235 | F2 = 0.5254
#  * Threshold = 0.36 | Recall = 0.4676 | Precision = 0.9072 | F1 = 0.6171 | F2 = 0.5178
#  * Threshold = 0.38 | Recall = 0.4576 | Precision = 0.9071 | F1 = 0.6083 | F2 = 0.5080
#  * Threshold = 0.40 | Recall = 0.4417 | Precision = 0.9134 | F1 = 0.5954 | F2 = 0.4926
#  * Threshold = 0.42 | Recall = 0.4287 | Precision = 0.9188 | F1 = 0.5846 | F2 = 0.4799
#  * Threshold = 0.44 | Recall = 0.4187 | Precision = 0.9211 | F1 = 0.5757 | F2 = 0.4700
#  * Threshold = 0.46 | Recall = 0.4108 | Precision = 0.9217 | F1 = 0.5683 | F2 = 0.4620
#  * Threshold = 0.48 | Recall = 0.4008 | Precision = 0.9199 | F1 = 0.5583 | F2 = 0.4518
#  * Threshold = 0.50 | Recall = 0.3878 | Precision = 0.9175 | F1 = 0.5452 | F2 = 0.4385
# --------------------------------------------------
#  -> Đang chạy Bootstrapping (50 vòng) để tìm ngưỡng Tối ưu (F2 cao nhất & Precision >= 0.7)...
#  -> Ngưỡng (Threshold) Tối ưu Median: 0.04
#  -> Hiệu năng tại ngưỡng 0.04:
#     * Recall    : 0.8305
#     * Precision : 0.7120 (Mục tiêu >= 0.7)
#     * F1-Score  : 0.7667
#     * F2-Score  : 0.8037 (Thang đo tối ưu chính)
#  -> Threshold Chốt Cuối Cùng: 0.040
# --- ĐÁNH GIÁ TRÊN TẬP: IN-DISTRIBUTION TEST (ID) ---
# AUC: 0.9914 | F1: 0.8758 | Precision: 0.7816 | Recall: 0.9959
#               precision    recall  f1-score   support
#
#            0       0.99      0.72      0.84      1211
#            1       0.78      1.00      0.88      1211
#
#     accuracy                           0.86      2422
#    macro avg       0.89      0.86      0.86      2422
# weighted avg       0.89      0.86      0.86      2422
#
#
# --- ĐÁNH GIÁ TRÊN TẬP: OUT-OF-DISTRIBUTION TEST (OOD Mù) ---
# AUC: 0.8529 | F1: 0.7778 | Precision: 0.7246 | Recall: 0.8395
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74      1003
#            1       0.72      0.84      0.78      1003
#
#     accuracy                           0.76      2006
#    macro avg       0.77      0.76      0.76      2006
# weighted avg       0.77      0.76      0.76      2006
#
#
# 5. Đang chạy Sanity Checks (Trên tập OOD Test mù)...
#     * Feature mạnh nhất: punctuation_density (Drop AUC: 0.0507)
#     [AN TOÀN] Không feature nào độc tôn. Mô hình học đặc trưng đa dạng.
#
# 6. Đang lưu Artifacts...
#  -> Hoàn tất! Artifacts được lưu tại: Artifacts/

# %%
hf_pusher = HuggingFaceModelPusher(
    repo_id="JuniorThanh/xgboost_final_streamlit",
    artifact_dir="Artifacts"
)

hf_pusher.push_to_hub(commit_message="Upload XGBoost OOD-Robust model and calibration artifacts")
# Out:
# 7. Đang đẩy model và artifacts từ thư mục 'Artifacts' lên Hugging Face Hub (JuniorThanh/xgboost_final_streamlit)...
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...calibration_curve_ood.png:  65%|######5   |  177kB /  272kB
#   ...curves_ood_validation.png:  65%|######5   |  180kB /  277kB
#   ...s/xgb_robust_final.joblib:  65%|######5   |  595kB /  914kB
#  -> Hoàn tất đẩy dữ liệu lên Hugging Face! Bạn có thể xem tại: https://huggingface.co/JuniorThanh/xgboost_final_streamlit

# %% [markdown]
# # CHẠY ỨNG DỤNG

# %%
def load_const_seeds(filepath="Data/const_seeds.json"):
    if not os.path.exists(filepath):
        raise FileNotFoundError(f"Lỗi không tìm thấy file cấu hình tại '{filepath}'.")

    try:
        with open(filepath, 'r', encoding='utf-8') as f:
            return json.load(f)
    except json.JSONDecodeError as e:
        raise ValueError(f"File '{filepath}' không chuẩn định dạng JSON. Chi tiết lỗi: {e}")
    except Exception as e:
        raise RuntimeError(f"Lỗi không xác định khi đọc file '{filepath}': {e}")

CONST_SEED = load_const_seeds()

# %%
class PipelineStep:
    def execute(self, df, text_col, label_col=None):
        raise NotImplementedError

# %%
class CausalSurprisalStep(PipelineStep):
    def __init__(self, model_name="NlpHUST/gpt2-vietnamese"):
        self.model_name = model_name
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.dtype = torch.float16 if torch.cuda.is_available() else torch.float32

    def safe(self, v):
        return 0.0 if np.isnan(v) or np.isinf(v) else float(v)

    def _aggregate_to_word_level(self, surprisal_array, word_ids):
        if len(surprisal_array) != len(word_ids):
            return surprisal_array
        word_surprisals = {}
        for surp, w_id in zip(surprisal_array, word_ids):
            if w_id is not None:
                word_surprisals[w_id] = word_surprisals.get(w_id, 0) + surp
        if not word_surprisals or len(surprisal_array) == 0 or len(word_ids) == 0:
            return np.array([])
        return np.array([word_surprisals[k] for k in sorted(word_surprisals.keys())])

    def execute(self, df, text_col, label_col=None):
        print("\n" + "="*60)
        print(" GIAI ĐOẠN 5A: CAUSAL SURPRISAL DYNAMICS (GPT-NEO) - PRODUCTION")
        print("="*60)

        feature_names = ['mean', 'var', 'tail', 'd2_entropy']
        metrics = {k: np.zeros(len(df)) for k in feature_names}

        print(f"[Causal LM] Đang tải lên VRAM: {self.model_name}...")
        try:
            tokenizer = AutoTokenizer.from_pretrained(self.model_name, use_fast=True)
            model = AutoModelForCausalLM.from_pretrained(self.model_name, torch_dtype=self.dtype)
            model.to(self.device)
            model.eval()
        except Exception as e:
            print(f"⚠️ Lỗi tải model {self.model_name}: {e}")
            return df

        loss_fct = torch.nn.CrossEntropyLoss(reduction='none')

        with torch.no_grad():
            for idx, text in enumerate(tqdm(df[text_col], desc="[GPT-Neo] Quét Causal")):
                try:
                    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=1024).to(self.device)
                    input_ids = inputs["input_ids"]

                    if input_ids.size(1) < 4:
                        continue

                    outputs = model(input_ids)
                    shift_logits = outputs.logits[..., :-1, :].contiguous()
                    shift_labels = input_ids[..., 1:].contiguous()

                    surprisal_tensor = loss_fct(shift_logits.view(-1, shift_logits.size(-1)), shift_labels.view(-1))
                    S_raw = surprisal_tensor.cpu().numpy().astype(np.float64)

                    word_ids = inputs.word_ids(batch_index=0)[1:]
                    S = self._aggregate_to_word_level(S_raw, word_ids)

                    if len(S) < 5 or np.std(S) < 1e-6:
                        continue

                    metrics['mean'][idx] = np.mean(S)
                    metrics['var'][idx] = np.var(S)
                    metrics['tail'][idx] = np.percentile(S, 95)

                    d1 = np.diff(S)
                    d2 = np.diff(d1)
                    if len(d2) > 10:
                        hist, _ = np.histogram(d2, bins=10, density=True)
                        metrics['d2_entropy'][idx] = entropy(hist + 1e-9)

                except Exception as e:
                    pass

        print(f"[Memory] Giải phóng VRAM của {self.model_name}...")
        del model, tokenizer
        gc.collect()

        if torch.cuda.is_available():
            torch.cuda.empty_cache()

        for k in feature_names:
            df[f'gpt_{k}'] = metrics[k]

        return df

# %%
class AdvancedLogicFeatureExtractor(PipelineStep):
    def __init__(self,
                 seeds=None,
                 pronoun_list=None,
                 verb_noise_list=None,
                 ngram_range=(2, 6),
                 min_df=5,
                 max_df=0.7,
                 production_markers_path=None):

        self.groups = ['causal', 'contrast', 'additive', 'temporal']

        if not seeds:
          raise ValueError("Thiếu file seed")

        self.seeds = seeds

        self.pronoun_list = pronoun_list or {
            'tôi', 'ta', 'chúng ta', 'chúng tôi', 'mình', 'bạn', 'các bạn', 'họ', 'bọn họ', 'anh', 'chị', 'em', 'ông', 'bà', 'chú', 'bác', 'nó', 'hắn', 'tao', 'mày', 'tớ', 'tụi', 'tụi nó', 'bọn', 'bọn nó', 'anh ấy', 'chị ấy', 'cô ấy', 'ông ấy', 'bà ấy', 'anh ta', 'chị ta', 'họ ta', 'cô', 'dì', 'dượng', 'cậu', 'mợ', 'thầy', 'con', 'cháu', 'người ta', 'ai đó', 'mọi người', 'chúng nó', 'tụi mình', 'bọn mình'
        }

        self.verb_noise_list = verb_noise_list or {
            'nghĩ', 'thấy', 'cho rằng', 'rằng', 'là', 'sẽ', 'đã', 'đang'
        }

        self.ngram_range = ngram_range
        self.min_df = min_df
        self.max_df = max_df

        self.dynamic_markers = {g: set() for g in self.groups}
        self.dynamic_blacklist = set()
        self.regex_patterns = {}

        self.production_markers_path = production_markers_path
        if self.production_markers_path:
            self._load_production_markers()
            self._compile_regex_from_seeds()

    def _is_noise(self, ngram):
        for p in self.pronoun_list:
            for v in self.verb_noise_list:
                if f"{p} {v}" in ngram:
                    return True

        if len(ngram.split()) > 6:
            return True

        return False

    def _build_dynamic_markers_in_memory(self, df, text_col):
        print("1. Đang cắt đầu câu (Sentence Starters)...")
        starters = []
        for text in df[text_col].dropna():
            sentences = sent_tokenize(str(text))
            for sent in sentences:
                words = sent.split()
                if len(words) >= 2:
                    starters.append(sent.lower())

        if not starters:
            print("⚠️ CẢNH BÁO: Dữ liệu trống. Sẽ sử dụng Seeds mặc định.")
            self._compile_regex_from_seeds()
            return

        print("2. Đang tạo N-gram và đếm tần suất...")
        vectorizer = CountVectorizer(ngram_range=self.ngram_range, min_df=self.min_df, max_df=self.max_df)
        X = vectorizer.fit_transform(starters)
        freqs = zip(vectorizer.get_feature_names_out(), X.sum(axis=0).tolist()[0])
        sorted_ngrams = sorted(freqs, key=lambda x: x[1], reverse=True)

        print("3. Khởi chạy Dynamic Noise Filter và phân loại (RAM)...")
        for ngram, freq in sorted_ngrams:
            if self._is_noise(ngram):
                self.dynamic_blacklist.add(ngram)
                continue

            for g, seed_words in self.seeds.items():
                if any(s in ngram for s in seed_words):
                    self.dynamic_markers[g].add(ngram)
                    break

        self._compile_regex_from_seeds()

        print(f"✅ Hoàn tất lưu pipeline N-gram vào bộ nhớ.")
        print(f"⚠️ Đã lọc tự động {len(self.dynamic_blacklist)} cụm nhiễu.")

    def _compile_regex_from_seeds(self):
        for g in self.groups:
            manual_seeds = set(self.seeds.get(g, []))
            dynamic_found = self.dynamic_markers[g]

            all_markers = manual_seeds.union(dynamic_found)

            if not all_markers:
                continue

            sorted_markers = sorted(list(all_markers), key=len, reverse=True)
            pattern = r'(?<!\w)(' + '|'.join(map(re.escape, sorted_markers)) + r')(?!\w)'
            self.regex_patterns[g] = re.compile(pattern, re.IGNORECASE | re.UNICODE)

    def _extract_logic_metrics(self, text):
        sentences = sent_tokenize(str(text))
        num_sentences = len(sentences)

        res = {f'{g}_count': 0 for g in self.groups}
        res['transition_count'] = 0

        if num_sentences == 0:
            return pd.Series(res)

        for i, sent in enumerate(sentences):
            sent_lower = sent.lower()
            is_transition = False

            for g in self.groups:
                if g not in self.regex_patterns:
                    continue

                pattern = self.regex_patterns[g]
                matches = list(pattern.finditer(sent_lower))
                count = len(matches)

                if count > 0:
                    res[f'{g}_count'] += count

                    if not is_transition and matches[0].start() <= 20:
                        is_transition = True

            if is_transition:
                res['transition_count'] += 1

        res['num_sentences'] = num_sentences
        return pd.Series(res)

    def export_markers_for_production(self, expected_logic_val, filepath="Data/logic_markers_prod.json"):
        export_data = {
            "markers": {k: list(v) for k, v in self.dynamic_markers.items()},
            "expected_logic": float(expected_logic_val)
        }
        with open(filepath, 'w', encoding='utf-8') as f:
            json.dump(export_data, f, ensure_ascii=False, indent=4)
        print(f"\n✅ Đã xuất cấu hình sang môi trường Production: {filepath}")

    def _load_production_markers(self):
        try:
            with open(self.production_markers_path, 'r', encoding='utf-8') as f:
                data = json.load(f)

            if "markers" in data:
                self.dynamic_markers = {k: set(v) for k, v in data["markers"].items()}
                self.saved_expected_logic = data.get("expected_logic", 0.0)
            else:
                self.dynamic_markers = {k: set(v) for k, v in data.items()}
                self.saved_expected_logic = 0.0

            print(f"✅ Đã nạp thành công N-gram & Mean từ EDA: {self.production_markers_path}")
        except Exception as e:
            print(f"❌ Lỗi nạp file N-gram Production: {e}")
            self.saved_expected_logic = 0.0

    def execute(self, df, text_col, label_col=None):
        print("\n" + "="*60)
        print(" PIPELINE: KHAI PHÁ N-GRAM & TRÍCH XUẤT ĐẶC TRƯNG LOGIC")
        print("="*60)

        if not self.production_markers_path:
            self._build_dynamic_markers_in_memory(df, text_col)

        if 'seg_length' not in df.columns:
            df['seg_length'] = df[text_col].apply(lambda x: len(str(x).split()))

        try:
            tqdm.pandas(desc="[Logic] Áp dụng Regex tính Metrics")
            metrics_df = df[text_col].progress_apply(self._extract_logic_metrics)
        except (AttributeError, NameError):
            metrics_df = df[text_col].apply(self._extract_logic_metrics)

        df = pd.concat([df, metrics_df], axis=1)

        for g in self.groups:
            df[f'{g}_density'] = df[f'{g}_count'] / (df['seg_length'] + 1e-6)

        df['logic_transition_points'] = df['transition_count'] / (df['num_sentences'] + 1e-6)

        densities = df[[f'{g}_density' for g in self.groups]]
        df['logic_mismatch_score'] = densities.std(axis=1)

        df['logic_density'] = sum(df[f'{g}_count'] for g in self.groups) / (df['seg_length'] + 1e-6)

        if self.production_markers_path:
            expected_logic = getattr(self, 'saved_expected_logic', 0.0)
        else:
            expected_logic = float(df['logic_density'].mean())
            self.export_markers_for_production(expected_logic, "Data/logic_markers_prod.json")

        df['logic_deviation'] = abs(df['logic_density'] - expected_logic)

        df = df.drop(columns=['logic_transition_points','num_sentences', 'transition_count'] + [f'{g}_count' for g in self.groups])

        return df

# %%
class SyntacticAndStructuralStep(PipelineStep):
    def __init__(self):
        raw_pronouns = [
            "tôi", "tao", "tớ", "mình", "ta", "chúng tôi", "chúng ta", "tụi tôi", "bọn tôi", "tụi mình",
            "bạn", "cậu", "mày", "mi", "các bạn", "tụi bây", "bọn mày", "nó", "hắn", "y", "người ta",
            "họ", "chúng nó", "tụi nó", "bọn họ", "ai", "gì", "nào", "bao nhiêu", "bao giờ"
        ]
        self.pronoun_set = set([p.replace(" ", "_") for p in raw_pronouns])

    def _compute_recombined_features(self, text):
        paragraphs = [p for p in text.split('\n') if p.strip()]
        sentences = []
        for p in paragraphs: sentences.extend(sent_tokenize(p))

        sent_words = [word_tokenize(s) for s in sentences]
        sent_lengths = [len(words) for words in sent_words]
        total_words = sum(sent_lengths)
        total_words_safe = max(1, total_words)

        sent_len_mean = float(np.mean(sent_lengths)) if sent_lengths else 0.0
        sent_len_var = float(np.var(sent_lengths)) if sent_lengths else 0.0
        sent_len_cv = sent_len_var / (sent_len_mean + 1e-6)

        comma_counts = [s.count(',') for s in sentences]
        punct_counts = [sum(1 for char in s if char in string.punctuation) for s in sentences]

        comma_density = sum(comma_counts) / total_words_safe
        punctuation_density = sum(punct_counts) / total_words_safe

        all_words_lower = [w.lower() for words in sent_words for w in words]
        total_pronouns = sum(1 for w in all_words_lower if w in self.pronoun_set)
        pronoun_ratio = total_pronouns / total_words_safe

        return (sent_len_cv, comma_density, punctuation_density, pronoun_ratio)

    def execute(self, df, text_col, label_col=None):
        res = df[text_col].apply(self._compute_recombined_features)
        cols = ['sent_len_cv', 'comma_density', 'punctuation_density', 'pronoun_ratio']
        df[cols] = pd.DataFrame(res.tolist(), index=df.index)
        return df

# %%
class PhoBERTFeaturePipeline(PipelineStep):
    def __init__(self, model_name="vinai/phobert-base-v2", batch_size=16):
        self.model_name = model_name
        self.batch_size = batch_size
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.max_length = 256
        self.stride = 128

    def _compute_cpu_features(self, text):
        if not isinstance(text, str) or not text.strip():
            return (0.0, 0.0, [])

        try:
            sentences = sent_tokenize(text)

            pos_var = 0.0
            try:
                tags = pos_tag(text)
                if tags:
                    pos_counts = Counter(tag for _, tag in tags)
                    total_tags = sum(pos_counts.values())
                    probs = [c / total_tags for c in pos_counts.values()]
                    pos_var = float(np.var(probs))
            except Exception:
                pass

            entity_grid = 0.0
            try:
                if len(sentences) > 1:
                    sentence_entities = []
                    for s in sentences:
                        entities = {w for w, _, _, tg in ner(s) if tg != 'O'}
                        entities.update(w for w, tg in pos_tag(s) if str(tg).startswith('N'))
                        sentence_entities.append(entities)

                    overlaps = [len(set1 & set2) / max(1, len(set1 | set2))
                                for set1, set2 in zip(sentence_entities[:-1], sentence_entities[1:])]
                    if overlaps:
                        entity_grid = float(np.mean(overlaps))
            except Exception:
                pass

            return (pos_var, entity_grid, sentences)

        except Exception:
            return (0.0, 0.0, [])

    def _mean_pooling(self, model_output, attention_mask):
        token_embeddings = model_output[0]
        input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
        return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

    def _get_sentence_embeddings(self, sentences, tokenizer, model):
        if not sentences: return np.array([])

        chunked_inputs = []
        sentence_to_chunk_map = []
        current_chunk_idx = 0

        tokenized_sents = tokenizer(sentences, add_special_tokens=False, return_attention_mask=False)['input_ids']

        for tokens in tokenized_sents:
            if len(tokens) <= self.max_length - 2:
                chunked_inputs.append([tokenizer.cls_token_id] + tokens + [tokenizer.sep_token_id])
                sentence_to_chunk_map.append([current_chunk_idx])
                current_chunk_idx += 1
            else:
                sent_chunks_idx = []
                for i in range(0, len(tokens), self.max_length - self.stride - 2):
                    window_tokens = tokens[i : i + (self.max_length - 2)]
                    chunked_inputs.append([tokenizer.cls_token_id] + window_tokens + [tokenizer.sep_token_id])
                    sent_chunks_idx.append(current_chunk_idx)
                    current_chunk_idx += 1
                sentence_to_chunk_map.append(sent_chunks_idx)

        chunk_embeddings = []
        model.eval()
        pad_id = tokenizer.pad_token_id

        with torch.no_grad():
            for i in range(0, len(chunked_inputs), self.batch_size):
                batch_tokens = chunked_inputs[i : i + self.batch_size]

                max_len = max(len(t) for t in batch_tokens)

                input_ids = torch.tensor(
                    [t + [pad_id] * (max_len - len(t)) for t in batch_tokens],
                    dtype=torch.long, device=self.device
                )
                attention_mask = (input_ids != pad_id).float()

                outputs = model(input_ids=input_ids, attention_mask=attention_mask)
                embeddings = self._mean_pooling(outputs, attention_mask)
                embeddings = torch.nn.functional.normalize(embeddings, p=2, dim=1)

                chunk_embeddings.append(embeddings.cpu().numpy())

        chunk_embeddings = np.concatenate(chunk_embeddings, axis=0)

        all_sentence_embeddings = np.empty((len(sentence_to_chunk_map), chunk_embeddings.shape[1]), dtype=np.float32)

        for idx, chunk_indices in enumerate(sentence_to_chunk_map):
            sent_embeds = chunk_embeddings[chunk_indices]
            final_sent_embed = np.mean(sent_embeds, axis=0)
            norm = np.linalg.norm(final_sent_embed)
            if norm > 0:
                final_sent_embed = final_sent_embed / norm
            all_sentence_embeddings[idx] = final_sent_embed

        return all_sentence_embeddings

    def execute(self, df, text_col, label_col=None, **kwargs):
        cpu_results = [self._compute_cpu_features(text) for text in df[text_col]]

        df['pos_distribution_variance'] = [x[0] for x in cpu_results]
        df['entity_grid_score'] = [x[1] for x in cpu_results]

        all_sentences = []
        text_sent_indices = []
        current_idx = 0

        for res in cpu_results:
            sents = res[2]
            n_sents = len(sents)
            text_sent_indices.append((current_idx, current_idx + n_sents))
            all_sentences.extend(sents)
            current_idx += n_sents

        if not all_sentences:
            for col in ['sentence_embedding_coherence', 'topic_drift_score', 'semantic_drift_score', 'embedding_distribution_entropy']:
                df[col] = 0.0
            return df

        tokenizer = None
        model = None
        try:
            tokenizer = AutoTokenizer.from_pretrained(self.model_name)
            model = AutoModel.from_pretrained(self.model_name).to(self.device)
            all_embeddings = self._get_sentence_embeddings(all_sentences, tokenizer, model)
        except Exception as e:
            print(f"Lỗi khởi tạo/chạy mô hình: {e}")
            for col in ['sentence_embedding_coherence', 'topic_drift_score', 'semantic_drift_score', 'embedding_distribution_entropy']:
                df[col] = 0.0
            return df
        finally:
            if model is not None:
                del model
            if tokenizer is not None:
                del tokenizer
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()

        n_docs = len(text_sent_indices)
        coherences = np.zeros(n_docs, dtype=np.float32)
        topic_drifts = np.zeros(n_docs, dtype=np.float32)
        sem_drifts = np.zeros(n_docs, dtype=np.float32)
        entropies = np.zeros(n_docs, dtype=np.float32)

        for doc_idx, (start, end) in enumerate(text_sent_indices):
            n = end - start
            if n < 2:
                continue

            doc_embeds = all_embeddings[start:end]

            sims = np.sum(doc_embeds[:-1] * doc_embeds[1:], axis=1)
            sims = np.clip(sims, -1.0, 1.0)

            coherences[doc_idx] = float(np.mean(sims))
            topic_drifts[doc_idx] = float(np.var(sims))

            sem_drift = 1.0 - np.clip(np.dot(doc_embeds[0], doc_embeds[-1]), -1.0, 1.0)
            sem_drifts[doc_idx] = float(sem_drift)

            try:
                centered_embeds = doc_embeds - np.mean(doc_embeds, axis=0)
                _, S, _ = np.linalg.svd(centered_embeds, full_matrices=False)
                explained_variance = (S ** 2) / (n - 1)
                total_var = np.sum(explained_variance)

                if total_var > 0:
                    probs = explained_variance / total_var
                    probs = probs[probs > 0]
                    entropies[doc_idx] = float(-np.sum(probs * np.log2(probs)))
            except np.linalg.LinAlgError:
                pass

        df['sentence_embedding_coherence'] = coherences
        df['topic_drift_score'] = topic_drifts
        df['semantic_drift_score'] = sem_drifts
        df['embedding_distribution_entropy'] = entropies

        return df

# %%
class InteractionFeatureStep(PipelineStep):
    def execute(self, df: pd.DataFrame, text_col: str, label_col: str) -> pd.DataFrame:
        out_df = df.copy()

        out_df['gpt_var_x_semantic_drift'] = out_df['gpt_var'] * out_df['semantic_drift_score']
        out_df['gpt_mean_x_embedding_coherence'] = out_df['gpt_mean'] * out_df['sentence_embedding_coherence']
        out_df['gpt_tail_x_semantic_drift'] = out_df['gpt_tail'] * out_df['semantic_drift_score']

        out_df['comma_density_x_gpt_var'] = out_df['comma_density'] * out_df['gpt_var']

        out_df['logic_deviation_x_embedding_coherence'] = out_df['logic_deviation'] * out_df['sentence_embedding_coherence']

        out_df['transition_density'] = (out_df['causal_density'] +
                                        out_df['contrast_density'] +
                                        out_df['additive_density'] +
                                        out_df['temporal_density'])

        out_df['embedding_coherence_x_entropy'] = out_df['sentence_embedding_coherence'] * out_df['embedding_distribution_entropy']
        out_df['semantic_drift_x_entropy'] = out_df['semantic_drift_score'] * out_df['embedding_distribution_entropy']

        out_df['semantic_drift_ratio'] = out_df['semantic_drift_score'] / (out_df['gpt_var'] + 1e-5)

        out_df['combo_gpt_sent_punct'] = out_df['gpt_var'] * out_df['sent_len_cv'] * out_df['punctuation_density']

        print("Hoàn thành tính toán các đặc trưng tương tác.")
        return out_df

# %%
class TextAnalyzerUI:
    def __init__(self, const_seeds):
        self.logic_extractor = AdvancedLogicFeatureExtractor(
            seeds=const_seeds,
            production_markers_path="Data/logic_markers_prod.json"
        )
        self.syntax_extractor = SyntacticAndStructuralStep()
        self.semantic_extractor = PhoBERTFeaturePipeline()
        self.causal_extractor = CausalSurprisalStep(
            model_name="NlpHUST/gpt2-vietnamese"
        )

        self.interaction_extractor = InteractionFeatureStep()

        self.disallowed_pattern = re.compile(
            r'[^a-zA-Z0-9\s\.,\?!\-\(\)\'"“”‘’/_%àáãạảăắằẳẵặâấầẩẫậèéẹẻẽêềếểễệđìíĩỉịòóõọỏôốồổỗộơớờởỡợùúũụủưứừửữựỳýỹỷỵÀÁÃẠẢĂẮẰẲẴẶÂẤẦẨẪẬÈÉẸẺẼÊỀẾỂỄỆĐÌÍĨỈỊÒÓÕỌỎÔỐỒỔỖỘƠỚỜỞỠỢÙÚŨỤỦƯỨỪỬỮỰỲÝỸỶỴ]+'
        )

    def _validate_and_clean(self, text):
        if not isinstance(text, str):
            return False, "Dữ liệu đầu vào phải là văn bản (String)."

        text = unicodedata.normalize('NFC', text.strip())
        text = re.sub(r'[\r\n\t]+', ' ', text)

        text = re.sub(r'(http[s]?://|www\.|<.*?>|\S+@\S+|#\w+|@\w+)', '', text)
        text = text.replace(":", "")
        text = re.sub(self.disallowed_pattern, ' ', text)
        text = re.sub(r'\s{2,}', ' ', text)
        text = text.strip()

        if not text:
            return False, "Văn bản trống hoặc chỉ chứa ký tự rác."

        upper_chars = sum(1 for c in text if c.isupper())
        if len(text) > 0 and (upper_chars / len(text)) > 0.2:
            text = text.lower()

        if text[0].isalpha() and not text[0].isupper():
            text = text[0].upper() + text[1:]

        if not text.endswith('.'):
            last_period_index = text.rfind('.')
            if last_period_index == -1:
                return False, "Văn bản phải chứa ít nhất một dấu chấm câu kết thúc."
            text = text[:last_period_index + 1]

        if not text[0].isalpha():
            return False, f"Văn bản phải bắt đầu bằng chữ cái (Hiện tại: '{text[0]}')."

        if text.count('"') % 2 != 0:
            return False, "Lỗi cú pháp: Số lượng dấu ngoặc kép không đồng đều."

        words = text.split()
        word_count = len(words)

        if word_count < 200 or word_count > 2000:
            return False, f"Độ dài không hợp lệ ({word_count} từ). Yêu cầu từ 200 đến 2000 từ."

        vietnamese_vowels = re.findall(r'[àáãạảăắằẳẵặâấầẩẫậèéẹẻẽêềếểễệđìíĩỉịòóõọỏôốồổỗộơớờởỡợùúũụủưứừửữựỳýỹỷỵ]', text.lower())
        if (len(vietnamese_vowels) / word_count) < 0.2:
            return False, "Tỷ lệ nguyên âm tiếng Việt quá thấp (Nghi ngờ Spam)."

        return True, text

    def process_request(self, user_input_text):
        is_valid, result = self._validate_and_clean(user_input_text)

        if not is_valid:
            return {
                "status": "error",
                "message": result,
                "features": None
            }

        try:
            df = pd.DataFrame([{"text": result}])
            df = self.logic_extractor.execute(df, text_col='text')
            df = self.syntax_extractor.execute(df, text_col='text')
            df = self.semantic_extractor.execute(df, text_col='text')
            df = self.causal_extractor.execute(df, text_col='text')

            df = df.drop(columns=['text', 'seg_length'], errors='ignore')
            features_dict = df.iloc[0].to_dict()

            return {
                "status": "success",
                "message": "Trích xuất đặc trưng thành công.",
                "features": features_dict
            }
        except Exception as e:
            return {
                "status": "error",
                "message": f"Lỗi trích xuất: {str(e)}",
                "features": None
            }

    def execute(self, df, text_col='text'):
        validation_results = df[text_col].apply(self._validate_and_clean)

        df['is_valid'] = validation_results.apply(lambda x: x[0])
        df['processed_text'] = validation_results.apply(lambda x: x[1])
        df['error_msg'] = validation_results.apply(lambda x: x[1] if not x[0] else None)

        valid_df = df[df['is_valid']].copy()
        invalid_df = df[~df['is_valid']].copy()

        if not valid_df.empty:
            valid_df = self.logic_extractor.execute(valid_df, text_col='processed_text')
            valid_df = self.syntax_extractor.execute(valid_df, text_col='processed_text')
            valid_df = self.semantic_extractor.execute(valid_df, text_col='processed_text')
            valid_df = self.causal_extractor.execute(valid_df, text_col='processed_text')
            valid_df = self.interaction_extractor.execute(valid_df, text_col='processed_text', label_col=None)

        result_df = pd.concat([valid_df, invalid_df], ignore_index=False)
        result_df = result_df.sort_index()

        return result_df

# %%
class BatchEvaluator:
    def __init__(self, text_analyzer, trained_model, model_config):
        self.analyzer = text_analyzer
        self.model = trained_model
        self.feature_names = model_config.get("features", [])
        self.threshold = model_config.get("optimal_threshold_ood")

        if not self.feature_names:
            print("CẢNH BÁO: Không tìm thấy danh sách 'features' trong config!")

    def evaluate_dataframe(self, df, text_col='text', label_col='label'):
        print(f"Bắt đầu đánh giá trên {len(df)} mẫu dữ liệu...\nNgưỡng: {self.threshold}")

        extracted_df = self.analyzer.execute(df.copy(), text_col=text_col)

        missing_cols = [col for col in self.feature_names if col not in extracted_df.columns]
        if missing_cols:
             print(f"LỖI NGHIÊM TRỌNG: Dữ liệu trích xuất thiếu các cột: {missing_cols}")
             return None

        valid_df = extracted_df[self.feature_names].fillna(0.0)

        if hasattr(self.model, "predict_proba"):
            raw_probs = self.model.predict_proba(valid_df)[:, 1]

            scaled_probs = np.where(
                raw_probs < self.threshold,
                (raw_probs / self.threshold) * 0.5,
                0.5 + ((raw_probs - self.threshold) / (1.0 - self.threshold)) * 0.5
            )

            probabilities = scaled_probs
            predictions = (scaled_probs >= 0.5).astype(int)

        else:
            probabilities = [None] * len(valid_df)
            predictions = self.model.predict(valid_df)

        extracted_df['predicted_label'] = predictions
        extracted_df['probability'] = probabilities

        if label_col in extracted_df.columns:
            extracted_df['is_correct'] = extracted_df['predicted_label'] == extracted_df[label_col]

        total_samples = len(df)
        valid_samples = len(extracted_df)

        print("\n" + "="*80)
        print(" BÁO CÁO KẾT QUẢ DỰ ĐOÁN TỔNG QUAN")
        print("="*80)
        print(f"Ngưỡng phân loại (Threshold) : {self.threshold:.4f}")
        print(f"Tổng số mẫu                : {total_samples}")
        print(f"Mẫu hợp lệ dự đoán thành công: {valid_samples}")

        if label_col in extracted_df.columns and valid_samples > 0:
            correct_predictions = extracted_df['is_correct'].sum()
            incorrect_predictions = valid_samples - correct_predictions
            accuracy = (correct_predictions / valid_samples * 100)
            print("-" * 80)
            print(f"Dự đoán ĐÚNG      : {correct_predictions}")
            print(f"Dự đoán SAI       : {incorrect_predictions}")
            print(f"Độ chính xác (Acc): {accuracy:.2f}%")

        print("\n" + "="*80)
        print(" DANH SÁCH CHI TIẾT CÁC MẪU DỮ LIỆU & ĐẶC TRƯNG")
        print("="*80)

        for index, row in extracted_df.iterrows():
            idx = index
            pred_lbl = row['predicted_label']
            prob = row['probability']
            snippet = str(row[text_col])[:70].replace('\n', ' ') + "..."

            if isinstance(prob, float):
                prob = f"{prob * 100:.2f}%"

            if label_col in row:
                true_lbl = row[label_col]
                is_correct = row['is_correct']
                mark = "ĐÚNG" if is_correct else "SAI "
                print(f"[ID: {idx:<3}] {mark} | Thực tế: {true_lbl:<3} | Dự đoán: {pred_lbl:<3} | Xác suất: {prob}")
            else:
                print(f"[ID: {idx:<3}] Dự đoán: {pred_lbl:<3} | Xác suất: {prob}")

            print(f"          Snippet: {snippet}")
            print("          [Chi tiết Đặc Trưng]:")

            feature_dict = {f: row.get(f) for f in self.feature_names}
            items = list(feature_dict.items())

            for i in range(0, len(items), 3):
                chunk = items[i:i+3]
                formatted_chunk = []
                for k, v in chunk:
                    if pd.isna(v):
                        formatted_chunk.append(f"{k}: NaN")
                    elif isinstance(v, float):
                        formatted_chunk.append(f"{k}: {v:.4f}")
                    else:
                        formatted_chunk.append(f"{k}: {v}")
                print("            " + " | ".join(formatted_chunk))

            print("-" * 80)

        return extracted_df

# %%
class TextModelTester:
    def __init__(self, model_path, config_path, const_seed=42):
        print("Đang khởi tạo hệ thống...")
        self.model_path = model_path
        self.config_path = config_path
        self.const_seed = const_seed

        try:
            self.trained_classifier = joblib.load(self.model_path)
            with open(self.config_path, 'r', encoding='utf-8') as f:
                self.model_config = json.load(f)
        except Exception as e:
            print(f"Lỗi khi nạp model hoặc config: {e}")
            raise

        self.analyzer_app = TextAnalyzerUI(const_seeds=self.const_seed)
        self.evaluator = BatchEvaluator(
            text_analyzer=self.analyzer_app,
            trained_model=self.trained_classifier,
            model_config=self.model_config
        )
        print("Hệ thống đã sẵn sàng!\n")

    def test_from_files(self, file_paths, report_path='Model/Reports/xgboost_evaluation_report.xlsx'):
        print("--- ĐANG CHẠY CHẾ ĐỘ TEST TỪ FILE ---")
        all_dataframes = []

        for file_path in file_paths:
            if os.path.exists(file_path):
                try:
                    if file_path.endswith('.csv'):
                        df_temp = pd.read_csv(file_path, sep=None, engine='python')
                    elif file_path.endswith(('.xls', '.xlsx')):
                        df_temp = pd.read_excel(file_path)
                    else:
                        print(f"Bỏ qua {file_path}: Định dạng không được hỗ trợ.")
                        continue

                    all_dataframes.append(df_temp)
                    print(f"Đã nạp thành công: {file_path} ({len(df_temp)} mẫu)")
                except Exception as e:
                    print(f"Lỗi đọc file {file_path}: {e}")
            else:
                print(f"Không tìm thấy file: {file_path}")

        if not all_dataframes:
            print("Không có dữ liệu hợp lệ để test.")
            return None

        combined_df = pd.concat(all_dataframes, ignore_index=True)
        print("Danh sách các cột đang có:", combined_df.columns.tolist())

        combined_df = combined_df.dropna(subset=['text', 'label'])
        print(f"Tổng hợp sau khi dọn dẹp: {len(combined_df)} mẫu hợp lệ.")

        if len(combined_df) == 0:
            print("Dữ liệu trống rỗng. Hãy kiểm tra lại file hoặc TÊN CỘT!")
            return None

        detailed_df = self.evaluator.evaluate_dataframe(combined_df, text_col='text', label_col='label')

        os.makedirs(os.path.dirname(report_path), exist_ok=True)
        cols_to_keep = ['text', 'label', 'probability', 'is_correct']
        existing_cols = [col for col in cols_to_keep if col in detailed_df.columns]

        detailed_df[existing_cols].to_excel(report_path, index=False)
        print(f"Đã xuất báo cáo ra file: {report_path}\n")

        return detailed_df

    def test_manual_input(self, text_input, true_label=None):
        print("--- ĐANG CHẠY CHẾ ĐỘ TEST THỦ CÔNG ---")

        if isinstance(text_input, str):
            text_input = [text_input]
            if true_label is not None and not isinstance(true_label, list):
                true_label = [true_label]

        df_manual = pd.DataFrame({'text': text_input})

        if true_label is not None:
            if len(true_label) != len(text_input):
                print("Lỗi: Số lượng text và nhãn (label) không khớp nhau!")
                return None
            df_manual['label'] = true_label
            label_col = 'label'
        else:
            df_manual['label'] = -1
            label_col = 'label'

        result_df = self.evaluator.evaluate_dataframe(df_manual, text_col='text', label_col=label_col)

        print("\nKẾT QUẢ DỰ ĐOÁN:")
        for idx, row in result_df.iterrows():
            print("-" * 40)
            print(f"Đoạn văn: {row['text'][:100]}...")
            print(f"Xác suất Nhãn 1 (Probability): {row.get('probability', 'N/A')}")
            if true_label is not None:
                print(f"Dự đoán đúng (is_correct): {row.get('is_correct', 'N/A')}")

        print("-" * 40, "\n")
        return result_df

# %%
tester = TextModelTester(
    model_path='Artifacts/xgb_robust_final.joblib',
    config_path='Artifacts/model_config.json',
    const_seed=CONST_SEED
)

TEST_FILES = [
    "Data/test_dataset.csv",
    "Data/ai_studio_code.csv"
]

df_report = tester.test_from_files(TEST_FILES)
# Out:
# Đang khởi tạo hệ thống...
# ✅ Đã nạp thành công N-gram & Mean từ EDA: Data/logic_markers_prod.json
# Hệ thống đã sẵn sàng!
#
# --- ĐANG CHẠY CHẾ ĐỘ TEST TỪ FILE ---
# Đã nạp thành công: Data/test_dataset.csv (27 mẫu)
# Đã nạp thành công: Data/ai_studio_code.csv (50 mẫu)
# Danh sách các cột đang có: ['text', 'label', 'origin']
# Tổng hợp sau khi dọn dẹp: 77 mẫu hợp lệ.
# Bắt đầu đánh giá trên 77 mẫu dữ liệu...
# Ngưỡng: 0.04
#
# ============================================================
#  PIPELINE: KHAI PHÁ N-GRAM & TRÍCH XUẤT ĐẶC TRƯNG LOGIC
# ============================================================
# [Logic] Áp dụng Regex tính Metrics: 100%|██████████| 76/76 [00:09<00:00,  8.42it/s]
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# ============================================================
#  GIAI ĐOẠN 5A: CAUSAL SURPRISAL DYNAMICS (GPT-NEO) - PRODUCTION
# ============================================================
# [Causal LM] Đang tải lên VRAM: NlpHUST/gpt2-vietnamese...
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# [GPT-Neo] Quét Causal: 100%|██████████| 76/76 [00:01<00:00, 47.84it/s]
# [Memory] Giải phóng VRAM của NlpHUST/gpt2-vietnamese...
# Hoàn thành tính toán các đặc trưng tương tác.
#
# ================================================================================
#  BÁO CÁO KẾT QUẢ DỰ ĐOÁN TỔNG QUAN
# ================================================================================
# Ngưỡng phân loại (Threshold) : 0.0400
# Tổng số mẫu                : 77
# Mẫu hợp lệ dự đoán thành công: 77
# --------------------------------------------------------------------------------
# Dự đoán ĐÚNG      : 55
# Dự đoán SAI       : 22
# Độ chính xác (Acc): 71.43%
#
# ================================================================================
#  DANH SÁCH CHI TIẾT CÁC MẪU DỮ LIỆU & ĐẶC TRƯNG
# ================================================================================
# [ID: 0  ] ĐÚNG | Thực tế: 0   | Dự đoán: 0   | Xác suất: 2.71%
#           Snippet: Nổ súng gần bữa tiệc ông Trump tham dự  Tổng thống Trump được mật vụ M...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0107 | additive_density: 0.0000 | logic_density: 0.0236
#             gpt_mean: 2.8003 | gpt_var: 7.7288 | gpt_tail: 7.7797
#             gpt_d2_entropy: 1.8544 | sent_len_cv: 2.5579 | comma_density: 0.0381
#             punctuation_density: 0.1218 | pos_distribution_variance: 0.0064 | entity_grid_score: 0.0696
#             sentence_embedding_coherence: 0.7396 | embedding_distribution_entropy: 4.0818 | gpt_var_x_semantic_drift: 2.1545
#             gpt_tail_x_semantic_drift: 2.1687 | comma_density_x_gpt_var: 0.2942 | embedding_coherence_x_entropy: 3.0190
#             combo_gpt_sent_punct: 2.4085
# --------------------------------------------------------------------------------
# [ID: 1  ] ĐÚNG | Thực tế: 0   | Dự đoán: 0   | Xác suất: 42.49%
#           Snippet: Ukraine tuyên bố tập kích sở chỉ huy Nga, khiến 12 sĩ quan thiệt mạng ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0154 | additive_density: 0.0039 | logic_density: 0.0212
#             gpt_mean: 3.0019 | gpt_var: 10.0826 | gpt_tail: 8.3313
#             gpt_d2_entropy: 1.2601 | sent_len_cv: 4.6068 | comma_density: 0.0417
#             punctuation_density: 0.1088 | pos_distribution_variance: 0.0072 | entity_grid_score: 0.0575
#             sentence_embedding_coherence: 0.7807 | embedding_distribution_entropy: 3.6372 | gpt_var_x_semantic_drift: 1.7324
#             gpt_tail_x_semantic_drift: 1.4315 | comma_density_x_gpt_var: 0.4201 | embedding_coherence_x_entropy: 2.8396
#             combo_gpt_sent_punct: 5.0534
# --------------------------------------------------------------------------------
# [ID: 2  ] ĐÚNG | Thực tế: 0   | Dự đoán: 0   | Xác suất: 42.57%
#           Snippet: Lò sản xuất 2.800 tấn mì tươi 'ngậm' hàn the, thủy tinh lỏng ở TP HCM ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0050 | additive_density: 0.0000 | logic_density: 0.0101
#             gpt_mean: 2.4332 | gpt_var: 7.6443 | gpt_tail: 7.7895
#             gpt_d2_entropy: 1.5033 | sent_len_cv: 2.7262 | comma_density: 0.0744
#             punctuation_density: 0.1637 | pos_distribution_variance: 0.0073 | entity_grid_score: 0.0316
#             sentence_embedding_coherence: 0.7770 | embedding_distribution_entropy: 3.1657 | gpt_var_x_semantic_drift: 1.4860
#             gpt_tail_x_semantic_drift: 1.5142 | comma_density_x_gpt_var: 0.5688 | embedding_coherence_x_entropy: 2.4597
#             combo_gpt_sent_punct: 3.4113
# --------------------------------------------------------------------------------
# [ID: 3  ] ĐÚNG | Thực tế: 0   | Dự đoán: 0   | Xác suất: 4.27%
#           Snippet: Thành Long từ chối 'Rush Hour 4' vì cát-xê chỉ 8 triệu USD  Tài tử Thà...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0046 | additive_density: 0.0000 | logic_density: 0.0068
#             gpt_mean: 3.1146 | gpt_var: 9.6508 | gpt_tail: 8.8855
#             gpt_d2_entropy: 1.7273 | sent_len_cv: 4.1467 | comma_density: 0.0435
#             punctuation_density: 0.1304 | pos_distribution_variance: 0.0054 | entity_grid_score: 0.0199
#             sentence_embedding_coherence: 0.7377 | embedding_distribution_entropy: 3.6735 | gpt_var_x_semantic_drift: 3.7724
#             gpt_tail_x_semantic_drift: 3.4732 | comma_density_x_gpt_var: 0.4196 | embedding_coherence_x_entropy: 2.7100
#             combo_gpt_sent_punct: 5.2199
# --------------------------------------------------------------------------------
# [ID: 4  ] ĐÚNG | Thực tế: 0   | Dự đoán: 0   | Xác suất: 6.94%
#           Snippet: Sự kỳ thị giới tính 'hiện hình' qua những cơn đau cơ thể  Sự kỳ thị và...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0110 | additive_density: 0.0000 | logic_density: 0.0110
#             gpt_mean: 2.9671 | gpt_var: 7.5386 | gpt_tail: 7.8895
#             gpt_d2_entropy: 2.0425 | sent_len_cv: 3.4365 | comma_density: 0.0546
#             punctuation_density: 0.1366 | pos_distribution_variance: 0.0078 | entity_grid_score: 0.0309
#             sentence_embedding_coherence: 0.6985 | embedding_distribution_entropy: 3.4245 | gpt_var_x_semantic_drift: 1.1689
#             gpt_tail_x_semantic_drift: 1.2233 | comma_density_x_gpt_var: 0.4119 | embedding_coherence_x_entropy: 2.3920
#             combo_gpt_sent_punct: 3.5391
# --------------------------------------------------------------------------------
# [ID: 5  ] SAI  | Thực tế: 1   | Dự đoán: 0   | Xác suất: 8.83%
#           Snippet: Nổ súng tại Washington Hilton: Tổng thống Trump sơ tán khẩn cấp, một m...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0105 | additive_density: 0.0000 | logic_density: 0.0189
#             gpt_mean: 2.8019 | gpt_var: 7.8990 | gpt_tail: 8.5156
#             gpt_d2_entropy: 1.9548 | sent_len_cv: 2.9304 | comma_density: 0.0420
#             punctuation_density: 0.1207 | pos_distribution_variance: 0.0072 | entity_grid_score: 0.0240
#             sentence_embedding_coherence: 0.7651 | embedding_distribution_entropy: 3.8566 | gpt_var_x_semantic_drift: 1.7502
#             gpt_tail_x_semantic_drift: 1.8868 | comma_density_x_gpt_var: 0.3317 | embedding_coherence_x_entropy: 2.9505
#             combo_gpt_sent_punct: 2.7947
# --------------------------------------------------------------------------------
# [ID: 6  ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 83.20%
#           Snippet: ĐÒN "CHÉM ĐẦU" TẠI DONETSK: Mưa UAV Xé Toạc Sở Chỉ Huy FSB Nga, Phơi B...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0135 | additive_density: 0.0068 | logic_density: 0.0236
#             gpt_mean: 3.8289 | gpt_var: 13.0477 | gpt_tail: 9.9180
#             gpt_d2_entropy: 1.2714 | sent_len_cv: 6.0303 | comma_density: 0.0420
#             punctuation_density: 0.1155 | pos_distribution_variance: 0.0062 | entity_grid_score: 0.0281
#             sentence_embedding_coherence: 0.7821 | embedding_distribution_entropy: 3.7961 | gpt_var_x_semantic_drift: 3.1232
#             gpt_tail_x_semantic_drift: 2.3740 | comma_density_x_gpt_var: 0.5482 | embedding_coherence_x_entropy: 2.9688
#             combo_gpt_sent_punct: 9.0914
# --------------------------------------------------------------------------------
# [ID: 7  ] SAI  | Thực tế: 1   | Dự đoán: 0   | Xác suất: 21.96%
#           Snippet: Quyết định mới đây của Thành Long và Chris Tucker đang khiến giới điện...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0110 | additive_density: 0.0088 | logic_density: 0.0308
#             gpt_mean: 2.8144 | gpt_var: 6.8613 | gpt_tail: 7.7881
#             gpt_d2_entropy: 2.0328 | sent_len_cv: 2.0106 | comma_density: 0.0399
#             punctuation_density: 0.0878 | pos_distribution_variance: 0.0059 | entity_grid_score: 0.0075
#             sentence_embedding_coherence: 0.7409 | embedding_distribution_entropy: 3.7207 | gpt_var_x_semantic_drift: 1.6691
#             gpt_tail_x_semantic_drift: 1.8946 | comma_density_x_gpt_var: 0.2737 | embedding_coherence_x_entropy: 2.7566
#             combo_gpt_sent_punct: 1.2108
# --------------------------------------------------------------------------------
# [ID: 8  ] SAI  | Thực tế: 1   | Dự đoán: 0   | Xác suất: 15.56%
#           Snippet: Sự kỳ thị giới tính hiện hình qua những cơn đau cơ thể Dưới lớp da của...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0087 | additive_density: 0.0022 | logic_density: 0.0108
#             gpt_mean: 3.2460 | gpt_var: 8.2481 | gpt_tail: 8.4992
#             gpt_d2_entropy: 1.9218 | sent_len_cv: 2.0463 | comma_density: 0.0676
#             punctuation_density: 0.1183 | pos_distribution_variance: 0.0111 | entity_grid_score: 0.0262
#             sentence_embedding_coherence: 0.7770 | embedding_distribution_entropy: 3.5252 | gpt_var_x_semantic_drift: 1.5341
#             gpt_tail_x_semantic_drift: 1.5808 | comma_density_x_gpt_var: 0.5576 | embedding_coherence_x_entropy: 2.7390
#             combo_gpt_sent_punct: 1.9968
# --------------------------------------------------------------------------------
# [ID: 9  ] ĐÚNG | Thực tế: 0   | Dự đoán: 0   | Xác suất: 19.70%
#           Snippet: USS Gerald R. Ford dường như sẽ rời Trung Đông trong vài ngày tới, kết...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0076 | additive_density: 0.0038 | logic_density: 0.0132
#             gpt_mean: 2.9275 | gpt_var: 9.9017 | gpt_tail: 8.6875
#             gpt_d2_entropy: 1.5156 | sent_len_cv: 4.5529 | comma_density: 0.0345
#             punctuation_density: 0.1172 | pos_distribution_variance: 0.0058 | entity_grid_score: 0.0505
#             sentence_embedding_coherence: 0.7412 | embedding_distribution_entropy: 3.6942 | gpt_var_x_semantic_drift: 1.3455
#             gpt_tail_x_semantic_drift: 1.1805 | comma_density_x_gpt_var: 0.3414 | embedding_coherence_x_entropy: 2.7382
#             combo_gpt_sent_punct: 5.2854
# --------------------------------------------------------------------------------
# [ID: 10 ] ĐÚNG | Thực tế: 0   | Dự đoán: 0   | Xác suất: 16.87%
#           Snippet: Quân đội Israel thử nghiệm lưới bảo vệ xe cơ giới, sau khi hứng chỉ tr...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0036 | additive_density: 0.0036 | logic_density: 0.0089
#             gpt_mean: 3.4560 | gpt_var: 9.7555 | gpt_tail: 9.0773
#             gpt_d2_entropy: 1.9084 | sent_len_cv: 2.9939 | comma_density: 0.0375
#             punctuation_density: 0.1083 | pos_distribution_variance: 0.0072 | entity_grid_score: 0.1130
#             sentence_embedding_coherence: 0.8150 | embedding_distribution_entropy: 3.7190 | gpt_var_x_semantic_drift: 2.2534
#             gpt_tail_x_semantic_drift: 2.0967 | comma_density_x_gpt_var: 0.3658 | embedding_coherence_x_entropy: 3.0309
#             combo_gpt_sent_punct: 3.1641
# --------------------------------------------------------------------------------
# [ID: 11 ] ĐÚNG | Thực tế: 0   | Dự đoán: 0   | Xác suất: 24.41%
#           Snippet: Nhờ cao điểm Tết và tăng bay châu Âu, Vietnam Airlines lãi sau thuế hơ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0194 | additive_density: 0.0043 | logic_density: 0.0281
#             gpt_mean: 2.3502 | gpt_var: 6.5775 | gpt_tail: 7.0930
#             gpt_d2_entropy: 1.5975 | sent_len_cv: 2.3470 | comma_density: 0.0562
#             punctuation_density: 0.1565 | pos_distribution_variance: 0.0068 | entity_grid_score: 0.1075
#             sentence_embedding_coherence: 0.7959 | embedding_distribution_entropy: 3.4636 | gpt_var_x_semantic_drift: 1.8824
#             gpt_tail_x_semantic_drift: 2.0300 | comma_density_x_gpt_var: 0.3699 | embedding_coherence_x_entropy: 2.7565
#             combo_gpt_sent_punct: 2.4157
# --------------------------------------------------------------------------------
# [ID: 12 ] ĐÚNG | Thực tế: 0   | Dự đoán: 0   | Xác suất: 32.99%
#           Snippet: Lợi nhuận VietinBank bứt phá và thu hẹp khoảng cách với "quán quân" Vi...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0178 | additive_density: 0.0045 | logic_density: 0.0290
#             gpt_mean: 2.2666 | gpt_var: 7.0530 | gpt_tail: 7.1684
#             gpt_d2_entropy: 1.4153 | sent_len_cv: 3.9730 | comma_density: 0.0538
#             punctuation_density: 0.1663 | pos_distribution_variance: 0.0071 | entity_grid_score: 0.0968
#             sentence_embedding_coherence: 0.8036 | embedding_distribution_entropy: 3.4550 | gpt_var_x_semantic_drift: 1.3523
#             gpt_tail_x_semantic_drift: 1.3744 | comma_density_x_gpt_var: 0.3794 | embedding_coherence_x_entropy: 2.7766
#             combo_gpt_sent_punct: 4.6588
# --------------------------------------------------------------------------------
# [ID: 13 ] ĐÚNG | Thực tế: 0   | Dự đoán: 0   | Xác suất: 9.21%
#           Snippet: Giá thuê đất công nghiệp tại khu vực phía Nam đã tăng hơn 2 lần sau gầ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0073 | additive_density: 0.0031 | logic_density: 0.0147
#             gpt_mean: 3.3151 | gpt_var: 6.8616 | gpt_tail: 7.7820
#             gpt_d2_entropy: 1.9577 | sent_len_cv: 4.1134 | comma_density: 0.0696
#             punctuation_density: 0.1255 | pos_distribution_variance: 0.0071 | entity_grid_score: 0.0696
#             sentence_embedding_coherence: 0.8040 | embedding_distribution_entropy: 4.1678 | gpt_var_x_semantic_drift: 1.9046
#             gpt_tail_x_semantic_drift: 2.1600 | comma_density_x_gpt_var: 0.4773 | embedding_coherence_x_entropy: 3.3509
#             combo_gpt_sent_punct: 3.5412
# --------------------------------------------------------------------------------
# [ID: 14 ] SAI  | Thực tế: 0   | Dự đoán: 1   | Xác suất: 50.43%
#           Snippet: Dù duy trì lối sống lành mạnh và ăn uống khoa học, người đàn ông Đài L...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0157 | additive_density: 0.0045 | logic_density: 0.0270
#             gpt_mean: 2.2353 | gpt_var: 6.2873 | gpt_tail: 7.1977
#             gpt_d2_entropy: 1.9280 | sent_len_cv: 4.8718 | comma_density: 0.0456
#             punctuation_density: 0.0883 | pos_distribution_variance: 0.0084 | entity_grid_score: 0.0902
#             sentence_embedding_coherence: 0.7992 | embedding_distribution_entropy: 3.3824 | gpt_var_x_semantic_drift: 1.0012
#             gpt_tail_x_semantic_drift: 1.1461 | comma_density_x_gpt_var: 0.2866 | embedding_coherence_x_entropy: 2.7033
#             combo_gpt_sent_punct: 2.7052
# --------------------------------------------------------------------------------
# [ID: 15 ] ĐÚNG | Thực tế: 0   | Dự đoán: 0   | Xác suất: 10.62%
#           Snippet: Lỗ tròn ở đuôi bấm móng tay không phải chi tiết trang trí, mà là cấu t...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0067 | additive_density: 0.0000 | logic_density: 0.0090
#             gpt_mean: 3.1656 | gpt_var: 9.0552 | gpt_tail: 8.2703
#             gpt_d2_entropy: 1.4359 | sent_len_cv: 3.3311 | comma_density: 0.0474
#             punctuation_density: 0.1247 | pos_distribution_variance: 0.0083 | entity_grid_score: 0.0395
#             sentence_embedding_coherence: 0.7409 | embedding_distribution_entropy: 3.8675 | gpt_var_x_semantic_drift: 2.7774
#             gpt_tail_x_semantic_drift: 2.5366 | comma_density_x_gpt_var: 0.4290 | embedding_coherence_x_entropy: 2.8654
#             combo_gpt_sent_punct: 3.7611
# --------------------------------------------------------------------------------
# [ID: 16 ] SAI  | Thực tế: 0   | Dự đoán: 1   | Xác suất: 51.30%
#           Snippet: Elon Musk cáo buộc OpenAI "phản bội sứ mệnh ban đầu", trong khi công t...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0155 | additive_density: 0.0000 | logic_density: 0.0244
#             gpt_mean: 3.0608 | gpt_var: 10.8190 | gpt_tail: 8.0305
#             gpt_d2_entropy: 1.1942 | sent_len_cv: 2.1305 | comma_density: 0.0521
#             punctuation_density: 0.1510 | pos_distribution_variance: 0.0063 | entity_grid_score: 0.0925
#             sentence_embedding_coherence: 0.8023 | embedding_distribution_entropy: 3.6658 | gpt_var_x_semantic_drift: 2.2918
#             gpt_tail_x_semantic_drift: 1.7011 | comma_density_x_gpt_var: 0.5635 | embedding_coherence_x_entropy: 2.9410
#             combo_gpt_sent_punct: 3.4815
# --------------------------------------------------------------------------------
# [ID: 17 ] ĐÚNG | Thực tế: 0   | Dự đoán: 0   | Xác suất: 7.96%
#           Snippet: Trong các email được công bố làm bằng chứng trước tòa, Musk nói ông cầ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0156 | additive_density: 0.0000 | logic_density: 0.0234
#             gpt_mean: 3.2027 | gpt_var: 8.7833 | gpt_tail: 8.3863
#             gpt_d2_entropy: 1.6314 | sent_len_cv: 4.0317 | comma_density: 0.0382
#             punctuation_density: 0.1316 | pos_distribution_variance: 0.0048 | entity_grid_score: 0.0949
#             sentence_embedding_coherence: 0.7570 | embedding_distribution_entropy: 3.9103 | gpt_var_x_semantic_drift: 1.6605
#             gpt_tail_x_semantic_drift: 1.5855 | comma_density_x_gpt_var: 0.3357 | embedding_coherence_x_entropy: 2.9602
#             combo_gpt_sent_punct: 4.6615
# --------------------------------------------------------------------------------
# [ID: 18 ] ĐÚNG | Thực tế: 0   | Dự đoán: 0   | Xác suất: 9.46%
#           Snippet: Quân đội Israel xác nhận một trận địa pháo binh bị drone của Hezbollah...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0018 | additive_density: 0.0037 | logic_density: 0.0110
#             gpt_mean: 3.0929 | gpt_var: 8.1643 | gpt_tail: 8.0938
#             gpt_d2_entropy: 1.5561 | sent_len_cv: 2.0819 | comma_density: 0.0288
#             punctuation_density: 0.1020 | pos_distribution_variance: 0.0065 | entity_grid_score: 0.0791
#             sentence_embedding_coherence: 0.8134 | embedding_distribution_entropy: 3.7523 | gpt_var_x_semantic_drift: 2.3006
#             gpt_tail_x_semantic_drift: 2.2807 | comma_density_x_gpt_var: 0.2353 | embedding_coherence_x_entropy: 3.0522
#             combo_gpt_sent_punct: 1.7337
# --------------------------------------------------------------------------------
# [ID: 19 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 85.56%
#           Snippet: “Sát thủ vô hình” trong từng nhịp thở: Khi sự tiện lợi đang âm thầm tư...
#           [Chi tiết Đặc Trưng]:
#             causal_density: NaN | additive_density: NaN | logic_density: NaN
#             gpt_mean: NaN | gpt_var: NaN | gpt_tail: NaN
#             gpt_d2_entropy: NaN | sent_len_cv: NaN | comma_density: NaN
#             punctuation_density: NaN | pos_distribution_variance: NaN | entity_grid_score: NaN
#             sentence_embedding_coherence: NaN | embedding_distribution_entropy: NaN | gpt_var_x_semantic_drift: NaN
#             gpt_tail_x_semantic_drift: NaN | comma_density_x_gpt_var: NaN | embedding_coherence_x_entropy: NaN
#             combo_gpt_sent_punct: NaN
# --------------------------------------------------------------------------------
# [ID: 20 ] SAI  | Thực tế: 1   | Dự đoán: 0   | Xác suất: 39.72%
#           Snippet: Khi “La bàn đạo đức” đối mặt với bão số: Sinh viên và những lằn ranh đ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0070 | additive_density: 0.0017 | logic_density: 0.0105
#             gpt_mean: 3.4499 | gpt_var: 9.5726 | gpt_tail: 9.0703
#             gpt_d2_entropy: 1.7821 | sent_len_cv: 6.4035 | comma_density: 0.0385
#             punctuation_density: 0.1349 | pos_distribution_variance: 0.0073 | entity_grid_score: 0.0328
#             sentence_embedding_coherence: 0.7969 | embedding_distribution_entropy: 3.7037 | gpt_var_x_semantic_drift: 1.4631
#             gpt_tail_x_semantic_drift: 1.3863 | comma_density_x_gpt_var: 0.3690 | embedding_coherence_x_entropy: 2.9515
#             combo_gpt_sent_punct: 8.2694
# --------------------------------------------------------------------------------
# [ID: 21 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 86.66%
#           Snippet: Đại học Mở TP.HCM: Môi trường học tập linh hoạt và bài toán cơ sở vật ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0118 | additive_density: 0.0118 | logic_density: 0.0260
#             gpt_mean: 2.3749 | gpt_var: 6.8625 | gpt_tail: 7.4324
#             gpt_d2_entropy: 1.6890 | sent_len_cv: 1.5604 | comma_density: 0.0597
#             punctuation_density: 0.1433 | pos_distribution_variance: 0.0072 | entity_grid_score: 0.0372
#             sentence_embedding_coherence: 0.8026 | embedding_distribution_entropy: 3.1118 | gpt_var_x_semantic_drift: 1.6103
#             gpt_tail_x_semantic_drift: 1.7440 | comma_density_x_gpt_var: 0.4097 | embedding_coherence_x_entropy: 2.4974
#             combo_gpt_sent_punct: 1.5343
# --------------------------------------------------------------------------------
# [ID: 22 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 99.76%
#           Snippet: Trong nhịp sống hiện đại, lo lắng dường như đã trở thành một “dịch bện...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0121 | additive_density: 0.0121 | logic_density: 0.0272
#             gpt_mean: 2.1087 | gpt_var: 4.6090 | gpt_tail: 6.2324
#             gpt_d2_entropy: 1.8341 | sent_len_cv: 2.2386 | comma_density: 0.0807
#             punctuation_density: 0.1368 | pos_distribution_variance: 0.0066 | entity_grid_score: 0.0000
#             sentence_embedding_coherence: 0.7652 | embedding_distribution_entropy: 3.5856 | gpt_var_x_semantic_drift: 1.1791
#             gpt_tail_x_semantic_drift: 1.5944 | comma_density_x_gpt_var: 0.3720 | embedding_coherence_x_entropy: 2.7436
#             combo_gpt_sent_punct: 1.4119
# --------------------------------------------------------------------------------
# [ID: 23 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 66.49%
#           Snippet: Đánh giá thực địa Trường Đại học Mở Thành phố Hồ Chí Minh Sáng 30/4, p...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0110 | additive_density: 0.0037 | logic_density: 0.0184
#             gpt_mean: 2.6071 | gpt_var: 7.7519 | gpt_tail: 8.0219
#             gpt_d2_entropy: 1.9833 | sent_len_cv: 0.7994 | comma_density: 0.0718
#             punctuation_density: 0.1282 | pos_distribution_variance: 0.0106 | entity_grid_score: 0.0348
#             sentence_embedding_coherence: 0.8339 | embedding_distribution_entropy: 2.7457 | gpt_var_x_semantic_drift: 1.2416
#             gpt_tail_x_semantic_drift: 1.2848 | comma_density_x_gpt_var: 0.5565 | embedding_coherence_x_entropy: 2.2898
#             combo_gpt_sent_punct: 0.7944
# --------------------------------------------------------------------------------
# [ID: 24 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 92.28%
#           Snippet: Đạo đức sinh viên năm 2026: Giữ nền tảng giữa thời đại biến động  Năm ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0021 | additive_density: 0.0126 | logic_density: 0.0189
#             gpt_mean: 2.2309 | gpt_var: 5.5394 | gpt_tail: 6.8711
#             gpt_d2_entropy: 1.7763 | sent_len_cv: 1.9710 | comma_density: 0.0565
#             punctuation_density: 0.1017 | pos_distribution_variance: 0.0095 | entity_grid_score: 0.0190
#             sentence_embedding_coherence: 0.7750 | embedding_distribution_entropy: 3.6855 | gpt_var_x_semantic_drift: 0.6570
#             gpt_tail_x_semantic_drift: 0.8149 | comma_density_x_gpt_var: 0.3130 | embedding_coherence_x_entropy: 2.8563
#             combo_gpt_sent_punct: 1.1103
# --------------------------------------------------------------------------------
# [ID: 25 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 99.63%
#           Snippet: Trong bối cảnh xã hội chuyển mình mạnh mẽ dưới tác động của công nghệ ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0081 | additive_density: 0.0061 | logic_density: 0.0203
#             gpt_mean: 2.4205 | gpt_var: 5.4463 | gpt_tail: 6.8395
#             gpt_d2_entropy: 1.9160 | sent_len_cv: 1.8933 | comma_density: 0.0649
#             punctuation_density: 0.1143 | pos_distribution_variance: 0.0061 | entity_grid_score: 0.0143
#             sentence_embedding_coherence: 0.8140 | embedding_distribution_entropy: 3.7328 | gpt_var_x_semantic_drift: 0.5913
#             gpt_tail_x_semantic_drift: 0.7426 | comma_density_x_gpt_var: 0.3537 | embedding_coherence_x_entropy: 3.0385
#             combo_gpt_sent_punct: 1.1785
# --------------------------------------------------------------------------------
# [ID: 26 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 50.43%
#           Snippet: Nhìn vào lịch sử kinh doanh, cái gọi là “trận thua” của những kẻ sau c...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0164 | additive_density: 0.0036 | logic_density: 0.0291
#             gpt_mean: 3.5637 | gpt_var: 8.4489 | gpt_tail: 8.8383
#             gpt_d2_entropy: 1.9735 | sent_len_cv: 3.7733 | comma_density: 0.0452
#             punctuation_density: 0.1032 | pos_distribution_variance: 0.0054 | entity_grid_score: 0.0133
#             sentence_embedding_coherence: 0.7507 | embedding_distribution_entropy: 4.0770 | gpt_var_x_semantic_drift: 1.5267
#             gpt_tail_x_semantic_drift: 1.5970 | comma_density_x_gpt_var: 0.3816 | embedding_coherence_x_entropy: 3.0604
#             combo_gpt_sent_punct: 3.2908
# --------------------------------------------------------------------------------
# [ID: 27 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 54.15%
#           Snippet: Việt Nam dẫn đầu khu vực về thu hút vốn FDI công nghệ cao trong quý I/...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0061 | additive_density: 0.0061 | logic_density: 0.0153
#             gpt_mean: 2.1792 | gpt_var: 6.2123 | gpt_tail: 7.0684
#             gpt_d2_entropy: 1.8490 | sent_len_cv: 4.8255 | comma_density: 0.0363
#             punctuation_density: 0.1129 | pos_distribution_variance: 0.0068 | entity_grid_score: 0.0137
#             sentence_embedding_coherence: 0.7619 | embedding_distribution_entropy: 3.2038 | gpt_var_x_semantic_drift: 1.1872
#             gpt_tail_x_semantic_drift: 1.3509 | comma_density_x_gpt_var: 0.2254 | embedding_coherence_x_entropy: 2.4409
#             combo_gpt_sent_punct: 3.3845
# --------------------------------------------------------------------------------
# [ID: 28 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 79.54%
#           Snippet: Trí tuệ nhân tạo (AI) thay đổi diện mạo ngành y tế: Từ chẩn đoán đến đ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0152 | additive_density: 0.0000 | logic_density: 0.0183
#             gpt_mean: 2.2408 | gpt_var: 5.2864 | gpt_tail: 6.9109
#             gpt_d2_entropy: 2.0863 | sent_len_cv: 3.1690 | comma_density: 0.0543
#             punctuation_density: 0.1279 | pos_distribution_variance: 0.0083 | entity_grid_score: 0.0309
#             sentence_embedding_coherence: 0.7940 | embedding_distribution_entropy: 3.0205 | gpt_var_x_semantic_drift: 0.9110
#             gpt_tail_x_semantic_drift: 1.1910 | comma_density_x_gpt_var: 0.2869 | embedding_coherence_x_entropy: 2.3983
#             combo_gpt_sent_punct: 2.1428
# --------------------------------------------------------------------------------
# [ID: 29 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 63.30%
#           Snippet: Khủng hoảng rác thải nhựa đại dương: Lời cảnh báo từ những hòn đảo du ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0194 | additive_density: 0.0000 | logic_density: 0.0259
#             gpt_mean: 2.3890 | gpt_var: 5.5834 | gpt_tail: 6.6631
#             gpt_d2_entropy: 1.9150 | sent_len_cv: 1.6887 | comma_density: 0.0480
#             punctuation_density: 0.1000 | pos_distribution_variance: 0.0076 | entity_grid_score: 0.0400
#             sentence_embedding_coherence: 0.7603 | embedding_distribution_entropy: 3.1829 | gpt_var_x_semantic_drift: 1.5378
#             gpt_tail_x_semantic_drift: 1.8351 | comma_density_x_gpt_var: 0.2680 | embedding_coherence_x_entropy: 2.4199
#             combo_gpt_sent_punct: 0.9429
# --------------------------------------------------------------------------------
# [ID: 30 ] SAI  | Thực tế: 1   | Dự đoán: 0   | Xác suất: 39.85%
#           Snippet: Thế hệ Z và áp lực 'phải thành công' trên mạng xã hội  Một nghiên cứu ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0128 | additive_density: 0.0064 | logic_density: 0.0224
#             gpt_mean: 2.7214 | gpt_var: 7.4360 | gpt_tail: 7.8477
#             gpt_d2_entropy: 1.8767 | sent_len_cv: 2.3471 | comma_density: 0.0235
#             punctuation_density: 0.1176 | pos_distribution_variance: 0.0082 | entity_grid_score: 0.0325
#             sentence_embedding_coherence: 0.7864 | embedding_distribution_entropy: 3.0289 | gpt_var_x_semantic_drift: 1.1243
#             gpt_tail_x_semantic_drift: 1.1865 | comma_density_x_gpt_var: 0.1750 | embedding_coherence_x_entropy: 2.3819
#             combo_gpt_sent_punct: 2.0533
# --------------------------------------------------------------------------------
# [ID: 31 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 81.13%
#           Snippet: Tương lai của xe điện: Pin thể rắn sẽ là bước ngoặt toàn cầu?  Ngành c...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0102 | additive_density: 0.0000 | logic_density: 0.0169
#             gpt_mean: 2.5086 | gpt_var: 8.1071 | gpt_tail: 7.3027
#             gpt_d2_entropy: 1.3288 | sent_len_cv: 2.4645 | comma_density: 0.0420
#             punctuation_density: 0.1218 | pos_distribution_variance: 0.0060 | entity_grid_score: 0.0261
#             sentence_embedding_coherence: 0.7828 | embedding_distribution_entropy: 3.1797 | gpt_var_x_semantic_drift: 1.6229
#             gpt_tail_x_semantic_drift: 1.4619 | comma_density_x_gpt_var: 0.3406 | embedding_coherence_x_entropy: 2.4892
#             combo_gpt_sent_punct: 2.4345
# --------------------------------------------------------------------------------
# [ID: 32 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 82.55%
#           Snippet: Nghệ thuật truyền thống trong dòng chảy hiện đại: Hồi sinh hay biến mấ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0000 | additive_density: 0.0061 | logic_density: 0.0092
#             gpt_mean: 2.3504 | gpt_var: 4.9540 | gpt_tail: 6.6375
#             gpt_d2_entropy: 2.0491 | sent_len_cv: 1.7344 | comma_density: 0.0317
#             punctuation_density: 0.0992 | pos_distribution_variance: 0.0068 | entity_grid_score: 0.0093
#             sentence_embedding_coherence: 0.8032 | embedding_distribution_entropy: 3.4220 | gpt_var_x_semantic_drift: 0.9941
#             gpt_tail_x_semantic_drift: 1.3319 | comma_density_x_gpt_var: 0.1573 | embedding_coherence_x_entropy: 2.7485
#             combo_gpt_sent_punct: 0.8524
# --------------------------------------------------------------------------------
# [ID: 33 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 74.18%
#           Snippet: Thị trường bất động sản 2025: Kỳ vọng vào phân khúc nhà ở xã hội  Sau ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0067 | additive_density: 0.0067 | logic_density: 0.0200
#             gpt_mean: 2.0797 | gpt_var: 5.3587 | gpt_tail: 6.8164
#             gpt_d2_entropy: 2.0320 | sent_len_cv: 1.7097 | comma_density: 0.0310
#             punctuation_density: 0.0929 | pos_distribution_variance: 0.0086 | entity_grid_score: 0.0500
#             sentence_embedding_coherence: 0.7894 | embedding_distribution_entropy: 3.0253 | gpt_var_x_semantic_drift: 0.7492
#             gpt_tail_x_semantic_drift: 0.9530 | comma_density_x_gpt_var: 0.1660 | embedding_coherence_x_entropy: 2.3881
#             combo_gpt_sent_punct: 0.8513
# --------------------------------------------------------------------------------
# [ID: 34 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 84.13%
#           Snippet: Giải mã hiện tượng 'Du lịch trả thù' và những hệ lụy đối với môi trườn...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0134 | additive_density: 0.0101 | logic_density: 0.0268
#             gpt_mean: 2.5129 | gpt_var: 5.4863 | gpt_tail: 6.6797
#             gpt_d2_entropy: 2.1385 | sent_len_cv: 1.2279 | comma_density: 0.0429
#             punctuation_density: 0.1288 | pos_distribution_variance: 0.0087 | entity_grid_score: 0.0093
#             sentence_embedding_coherence: 0.7904 | embedding_distribution_entropy: 3.0527 | gpt_var_x_semantic_drift: 0.8984
#             gpt_tail_x_semantic_drift: 1.0938 | comma_density_x_gpt_var: 0.2355 | embedding_coherence_x_entropy: 2.4128
#             combo_gpt_sent_punct: 0.8674
# --------------------------------------------------------------------------------
# [ID: 35 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 59.49%
#           Snippet: Cách mạng nông nghiệp 4.0: Khi nông dân làm chủ robot và dữ liệu lớn  ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0137 | additive_density: 0.0103 | logic_density: 0.0308
#             gpt_mean: 2.3573 | gpt_var: 5.9942 | gpt_tail: 7.5652
#             gpt_d2_entropy: 2.1522 | sent_len_cv: 3.9662 | comma_density: 0.0591
#             punctuation_density: 0.1392 | pos_distribution_variance: 0.0077 | entity_grid_score: 0.0000
#             sentence_embedding_coherence: 0.7820 | embedding_distribution_entropy: 2.8520 | gpt_var_x_semantic_drift: 0.9842
#             gpt_tail_x_semantic_drift: 1.2421 | comma_density_x_gpt_var: 0.3541 | embedding_coherence_x_entropy: 2.2304
#             combo_gpt_sent_punct: 3.3104
# --------------------------------------------------------------------------------
# [ID: 36 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 51.77%
#           Snippet: Nguy cơ từ 'Deepfake' và cuộc chiến bảo vệ sự thật trong kỷ nguyên số ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0033 | additive_density: 0.0033 | logic_density: 0.0100
#             gpt_mean: 2.7854 | gpt_var: 7.9164 | gpt_tail: 7.2883
#             gpt_d2_entropy: 1.3949 | sent_len_cv: 1.7833 | comma_density: 0.0417
#             punctuation_density: 0.1083 | pos_distribution_variance: 0.0073 | entity_grid_score: 0.0461
#             sentence_embedding_coherence: 0.7911 | embedding_distribution_entropy: 3.0690 | gpt_var_x_semantic_drift: 1.6867
#             gpt_tail_x_semantic_drift: 1.5528 | comma_density_x_gpt_var: 0.3298 | embedding_coherence_x_entropy: 2.4279
#             combo_gpt_sent_punct: 1.5294
# --------------------------------------------------------------------------------
# [ID: 37 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 81.06%
#           Snippet: Phát triển kinh tế đêm: Mỏ vàng bị bỏ ngỏ của du lịch Việt Nam  Trong ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0102 | additive_density: 0.0068 | logic_density: 0.0273
#             gpt_mean: 2.4438 | gpt_var: 5.7923 | gpt_tail: 7.0324
#             gpt_d2_entropy: 2.1039 | sent_len_cv: 2.3357 | comma_density: 0.0511
#             punctuation_density: 0.1191 | pos_distribution_variance: 0.0068 | entity_grid_score: 0.0366
#             sentence_embedding_coherence: 0.7756 | embedding_distribution_entropy: 2.9044 | gpt_var_x_semantic_drift: 1.0638
#             gpt_tail_x_semantic_drift: 1.2916 | comma_density_x_gpt_var: 0.2958 | embedding_coherence_x_entropy: 2.2526
#             combo_gpt_sent_punct: 1.6120
# --------------------------------------------------------------------------------
# [ID: 38 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 55.45%
#           Snippet: Cơn sốt đào tạo ngành Bán dẫn: Cơ hội hay trào lưu nhất thời?  Với sự ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0099 | additive_density: 0.0066 | logic_density: 0.0197
#             gpt_mean: 2.5048 | gpt_var: 6.9847 | gpt_tail: 7.2088
#             gpt_d2_entropy: 1.7574 | sent_len_cv: 1.3617 | comma_density: 0.0380
#             punctuation_density: 0.1266 | pos_distribution_variance: 0.0085 | entity_grid_score: 0.0321
#             sentence_embedding_coherence: 0.8071 | embedding_distribution_entropy: 3.2206 | gpt_var_x_semantic_drift: 1.6184
#             gpt_tail_x_semantic_drift: 1.6704 | comma_density_x_gpt_var: 0.2652 | embedding_coherence_x_entropy: 2.5994
#             combo_gpt_sent_punct: 1.2040
# --------------------------------------------------------------------------------
# [ID: 39 ] SAI  | Thực tế: 1   | Dự đoán: 0   | Xác suất: 42.05%
#           Snippet: Sức khỏe tâm thần nơi công sở: Khi sự im lặng không còn là vàng  Stres...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0180 | additive_density: 0.0072 | logic_density: 0.0252
#             gpt_mean: 2.5660 | gpt_var: 6.8588 | gpt_tail: 7.6291
#             gpt_d2_entropy: 1.8592 | sent_len_cv: 1.8972 | comma_density: 0.0376
#             punctuation_density: 0.1362 | pos_distribution_variance: 0.0073 | entity_grid_score: 0.0349
#             sentence_embedding_coherence: 0.7607 | embedding_distribution_entropy: 3.0275 | gpt_var_x_semantic_drift: 1.2233
#             gpt_tail_x_semantic_drift: 1.3607 | comma_density_x_gpt_var: 0.2576 | embedding_coherence_x_entropy: 2.3030
#             combo_gpt_sent_punct: 1.7717
# --------------------------------------------------------------------------------
# [ID: 40 ] SAI  | Thực tế: 1   | Dự đoán: 0   | Xác suất: 11.56%
#           Snippet: Dòng vốn đầu tư vào Startup Việt: Từ số lượng sang chất lượng  Sau gia...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0101 | additive_density: 0.0000 | logic_density: 0.0135
#             gpt_mean: 2.6233 | gpt_var: 6.7240 | gpt_tail: 7.9197
#             gpt_d2_entropy: 2.1037 | sent_len_cv: 2.5333 | comma_density: 0.0375
#             punctuation_density: 0.1292 | pos_distribution_variance: 0.0076 | entity_grid_score: 0.0131
#             sentence_embedding_coherence: 0.7601 | embedding_distribution_entropy: 3.0197 | gpt_var_x_semantic_drift: 1.1884
#             gpt_tail_x_semantic_drift: 1.3997 | comma_density_x_gpt_var: 0.2521 | embedding_coherence_x_entropy: 2.2952
#             combo_gpt_sent_punct: 2.2002
# --------------------------------------------------------------------------------
# [ID: 41 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 54.55%
#           Snippet: Thực phẩm thực vật (Plant-based) và xu hướng tiêu dùng xanh tại Việt N...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0138 | additive_density: 0.0034 | logic_density: 0.0276
#             gpt_mean: 2.4691 | gpt_var: 6.6801 | gpt_tail: 7.1676
#             gpt_d2_entropy: 1.5714 | sent_len_cv: 3.1678 | comma_density: 0.0300
#             punctuation_density: 0.1202 | pos_distribution_variance: 0.0055 | entity_grid_score: 0.0251
#             sentence_embedding_coherence: 0.7498 | embedding_distribution_entropy: 3.0180 | gpt_var_x_semantic_drift: 1.9322
#             gpt_tail_x_semantic_drift: 2.0732 | comma_density_x_gpt_var: 0.2007 | embedding_coherence_x_entropy: 2.2629
#             combo_gpt_sent_punct: 2.5430
# --------------------------------------------------------------------------------
# [ID: 42 ] SAI  | Thực tế: 1   | Dự đoán: 0   | Xác suất: 44.67%
#           Snippet: Bảo vệ bản quyền trong kỷ nguyên AI: Bài toán khó cho giới sáng tạo  S...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0100 | additive_density: 0.0000 | logic_density: 0.0133
#             gpt_mean: 2.7650 | gpt_var: 10.1386 | gpt_tail: 7.5746
#             gpt_d2_entropy: 1.1430 | sent_len_cv: 3.4813 | comma_density: 0.0252
#             punctuation_density: 0.1008 | pos_distribution_variance: 0.0071 | entity_grid_score: 0.0633
#             sentence_embedding_coherence: 0.7629 | embedding_distribution_entropy: 3.1562 | gpt_var_x_semantic_drift: 2.3467
#             gpt_tail_x_semantic_drift: 1.7532 | comma_density_x_gpt_var: 0.2556 | embedding_coherence_x_entropy: 2.4077
#             combo_gpt_sent_punct: 3.5592
# --------------------------------------------------------------------------------
# [ID: 43 ] SAI  | Thực tế: 1   | Dự đoán: 0   | Xác suất: 28.75%
#           Snippet: Cuộc đua vào vũ trụ của các tỷ phú: Khát vọng nhân loại hay thú vui xa...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0066 | additive_density: 0.0000 | logic_density: 0.0166
#             gpt_mean: 2.6641 | gpt_var: 7.1558 | gpt_tail: 7.5057
#             gpt_d2_entropy: 1.6940 | sent_len_cv: 1.1994 | comma_density: 0.0338
#             punctuation_density: 0.1013 | pos_distribution_variance: 0.0067 | entity_grid_score: 0.0152
#             sentence_embedding_coherence: 0.7484 | embedding_distribution_entropy: 3.2739 | gpt_var_x_semantic_drift: 1.8545
#             gpt_tail_x_semantic_drift: 1.9452 | comma_density_x_gpt_var: 0.2415 | embedding_coherence_x_entropy: 2.4501
#             combo_gpt_sent_punct: 0.8691
# --------------------------------------------------------------------------------
# [ID: 44 ] SAI  | Thực tế: 1   | Dự đoán: 0   | Xác suất: 10.18%
#           Snippet: Văn hóa 'Hủy bỏ' (Cancel Culture): Ranh giới giữa công lý mạng và bạo ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0035 | additive_density: 0.0000 | logic_density: 0.0106
#             gpt_mean: 2.8250 | gpt_var: 7.8630 | gpt_tail: 7.8070
#             gpt_d2_entropy: 1.7572 | sent_len_cv: 4.9661 | comma_density: 0.0357
#             punctuation_density: 0.1295 | pos_distribution_variance: 0.0071 | entity_grid_score: 0.0158
#             sentence_embedding_coherence: 0.7680 | embedding_distribution_entropy: 3.0573 | gpt_var_x_semantic_drift: 1.1188
#             gpt_tail_x_semantic_drift: 1.1109 | comma_density_x_gpt_var: 0.2808 | embedding_coherence_x_entropy: 2.3481
#             combo_gpt_sent_punct: 5.0554
# --------------------------------------------------------------------------------
# [ID: 45 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 77.83%
#           Snippet: Cà phê đặc sản Việt Nam: Hành trình nâng tầm giá trị hạt Robusta  Từ l...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0104 | additive_density: 0.0139 | logic_density: 0.0278
#             gpt_mean: 2.6557 | gpt_var: 6.5549 | gpt_tail: 7.1760
#             gpt_d2_entropy: 1.8385 | sent_len_cv: 1.2696 | comma_density: 0.0435
#             punctuation_density: 0.1217 | pos_distribution_variance: 0.0061 | entity_grid_score: 0.0931
#             sentence_embedding_coherence: 0.7938 | embedding_distribution_entropy: 3.0498 | gpt_var_x_semantic_drift: 1.2807
#             gpt_tail_x_semantic_drift: 1.4020 | comma_density_x_gpt_var: 0.2850 | embedding_coherence_x_entropy: 2.4211
#             combo_gpt_sent_punct: 1.0131
# --------------------------------------------------------------------------------
# [ID: 46 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 65.49%
#           Snippet: Sự lên ngôi của thể thao điện tử (E-sports): Khi game không còn là vô ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0069 | additive_density: 0.0069 | logic_density: 0.0173
#             gpt_mean: 2.4034 | gpt_var: 6.0734 | gpt_tail: 7.0336
#             gpt_d2_entropy: 2.0064 | sent_len_cv: 2.0435 | comma_density: 0.0478
#             punctuation_density: 0.1609 | pos_distribution_variance: 0.0067 | entity_grid_score: 0.0053
#             sentence_embedding_coherence: 0.7717 | embedding_distribution_entropy: 3.0687 | gpt_var_x_semantic_drift: 1.1047
#             gpt_tail_x_semantic_drift: 1.2793 | comma_density_x_gpt_var: 0.2905 | embedding_coherence_x_entropy: 2.3681
#             combo_gpt_sent_punct: 1.9965
# --------------------------------------------------------------------------------
# [ID: 47 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 50.39%
#           Snippet: Bình đẳng giới trong lĩnh vực STEM: Phá bỏ rào cản 'vùng cấm'  Mặc dù ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0000 | additive_density: 0.0073 | logic_density: 0.0110
#             gpt_mean: 2.6273 | gpt_var: 6.6358 | gpt_tail: 7.2982
#             gpt_d2_entropy: 1.8822 | sent_len_cv: 2.1147 | comma_density: 0.0553
#             punctuation_density: 0.1567 | pos_distribution_variance: 0.0084 | entity_grid_score: 0.0069
#             sentence_embedding_coherence: 0.8044 | embedding_distribution_entropy: 2.9071 | gpt_var_x_semantic_drift: 1.5903
#             gpt_tail_x_semantic_drift: 1.7490 | comma_density_x_gpt_var: 0.3670 | embedding_coherence_x_entropy: 2.3386
#             combo_gpt_sent_punct: 2.1987
# --------------------------------------------------------------------------------
# [ID: 48 ] SAI  | Thực tế: 1   | Dự đoán: 0   | Xác suất: 31.44%
#           Snippet: Xu hướng làm việc 'Hybrid': Sự cân bằng giữa linh hoạt và hiệu suất  S...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0217 | additive_density: 0.0036 | logic_density: 0.0290
#             gpt_mean: 2.7099 | gpt_var: 6.6181 | gpt_tail: 7.8910
#             gpt_d2_entropy: 2.0506 | sent_len_cv: 1.7791 | comma_density: 0.0465
#             punctuation_density: 0.1209 | pos_distribution_variance: 0.0083 | entity_grid_score: 0.0148
#             sentence_embedding_coherence: 0.7994 | embedding_distribution_entropy: 3.1174 | gpt_var_x_semantic_drift: 1.5109
#             gpt_tail_x_semantic_drift: 1.8015 | comma_density_x_gpt_var: 0.3078 | embedding_coherence_x_entropy: 2.4921
#             combo_gpt_sent_punct: 1.4238
# --------------------------------------------------------------------------------
# [ID: 49 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 81.16%
#           Snippet: Giáo dục STEM cho trẻ em: Đầu tư cho tương lai từ những dòng code đầu ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0035 | additive_density: 0.0035 | logic_density: 0.0141
#             gpt_mean: 2.2081 | gpt_var: 5.0106 | gpt_tail: 6.3535
#             gpt_d2_entropy: 1.9033 | sent_len_cv: 6.5889 | comma_density: 0.0400
#             punctuation_density: 0.1200 | pos_distribution_variance: 0.0065 | entity_grid_score: 0.0000
#             sentence_embedding_coherence: 0.7406 | embedding_distribution_entropy: 2.8613 | gpt_var_x_semantic_drift: 0.7066
#             gpt_tail_x_semantic_drift: 0.8960 | comma_density_x_gpt_var: 0.2004 | embedding_coherence_x_entropy: 2.1190
#             combo_gpt_sent_punct: 3.9617
# --------------------------------------------------------------------------------
# [ID: 50 ] SAI  | Thực tế: 1   | Dự đoán: 0   | Xác suất: 6.36%
#           Snippet: Tương lai của báo chí truyền thống: Thích nghi hay bị đào thải?  Sự bù...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0034 | additive_density: 0.0034 | logic_density: 0.0138
#             gpt_mean: 2.9323 | gpt_var: 7.2925 | gpt_tail: 7.8379
#             gpt_d2_entropy: 1.9027 | sent_len_cv: 3.2376 | comma_density: 0.0307
#             punctuation_density: 0.1053 | pos_distribution_variance: 0.0088 | entity_grid_score: 0.0336
#             sentence_embedding_coherence: 0.8014 | embedding_distribution_entropy: 3.1194 | gpt_var_x_semantic_drift: 1.8320
#             gpt_tail_x_semantic_drift: 1.9690 | comma_density_x_gpt_var: 0.2239 | embedding_coherence_x_entropy: 2.4999
#             combo_gpt_sent_punct: 2.4853
# --------------------------------------------------------------------------------
# [ID: 51 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 84.17%
#           Snippet: Khai thác tài nguyên biển bền vững: Giấc mơ làm giàu từ đại dương xanh...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0000 | additive_density: 0.0142 | logic_density: 0.0178
#             gpt_mean: 2.3518 | gpt_var: 5.4511 | gpt_tail: 6.7227
#             gpt_d2_entropy: 1.6031 | sent_len_cv: 0.9259 | comma_density: 0.0323
#             punctuation_density: 0.1290 | pos_distribution_variance: 0.0086 | entity_grid_score: 0.0179
# ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0040 | additive_density: 0.0079 | logic_density: 0.0159
#             gpt_mean: 2.6081 | gpt_var: 7.5902 | gpt_tail: 8.0812
#             gpt_d2_entropy: 2.0414 | sent_len_cv: 1.4174 | comma_density: 0.0324
#             punctuation_density: 0.1027 | pos_distribution_variance: 0.0088 | entity_grid_score: 0.0069
#             sentence_embedding_coherence: 0.8010 | embedding_distribution_entropy: 2.9166 | gpt_var_x_semantic_drift: 1.0949
#             gpt_tail_x_semantic_drift: 1.1657 | comma_density_x_gpt_var: 0.2462 | embedding_coherence_x_entropy: 2.3363
#             combo_gpt_sent_punct: 1.1049
# --------------------------------------------------------------------------------
# [ID: 60 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 66.60%
#           Snippet: Thành phố thông minh (Smart City): Cuộc sống dễ dàng hơn nhờ dữ liệu  ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0000 | additive_density: 0.0073 | logic_density: 0.0109
#             gpt_mean: 2.3845 | gpt_var: 5.9806 | gpt_tail: 6.7010
#             gpt_d2_entropy: 1.9638 | sent_len_cv: 2.3100 | comma_density: 0.0488
#             punctuation_density: 0.1366 | pos_distribution_variance: 0.0070 | entity_grid_score: 0.0000
#             sentence_embedding_coherence: 0.7917 | embedding_distribution_entropy: 2.8828 | gpt_var_x_semantic_drift: 1.3308
#             gpt_tail_x_semantic_drift: 1.4911 | comma_density_x_gpt_var: 0.2917 | embedding_coherence_x_entropy: 2.2824
#             combo_gpt_sent_punct: 1.8870
# --------------------------------------------------------------------------------
# [ID: 61 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 54.85%
#           Snippet: Sự dịch chuyển của dòng vốn đầu tư mạo hiểm vào lĩnh vực AI tại Đông N...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0068 | additive_density: 0.0000 | logic_density: 0.0136
#             gpt_mean: 2.5320 | gpt_var: 5.8121 | gpt_tail: 7.0340
#             gpt_d2_entropy: 2.0847 | sent_len_cv: 2.5040 | comma_density: 0.0312
#             punctuation_density: 0.0938 | pos_distribution_variance: 0.0067 | entity_grid_score: 0.0125
#             sentence_embedding_coherence: 0.8078 | embedding_distribution_entropy: 2.8857 | gpt_var_x_semantic_drift: 1.4527
#             gpt_tail_x_semantic_drift: 1.7581 | comma_density_x_gpt_var: 0.1816 | embedding_coherence_x_entropy: 2.3309
#             combo_gpt_sent_punct: 1.3644
# --------------------------------------------------------------------------------
# [ID: 62 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 51.26%
#           Snippet: Tiềm năng của năng lượng sóng biển: Nguồn điện sạch chưa được khai phá...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0076 | additive_density: 0.0038 | logic_density: 0.0189
#             gpt_mean: 2.4019 | gpt_var: 5.3541 | gpt_tail: 6.9527
#             gpt_d2_entropy: 2.0165 | sent_len_cv: 1.4238 | comma_density: 0.0341
#             punctuation_density: 0.0976 | pos_distribution_variance: 0.0085 | entity_grid_score: 0.1021
#             sentence_embedding_coherence: 0.8384 | embedding_distribution_entropy: 2.7084 | gpt_var_x_semantic_drift: 0.7187
#             gpt_tail_x_semantic_drift: 0.9333 | comma_density_x_gpt_var: 0.1828 | embedding_coherence_x_entropy: 2.2708
#             combo_gpt_sent_punct: 0.7437
# --------------------------------------------------------------------------------
# [ID: 63 ] SAI  | Thực tế: 1   | Dự đoán: 0   | Xác suất: 26.43%
#           Snippet: Văn hóa đọc trong thời đại số: Sự chuyển mình của những trang sách  Nh...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0000 | additive_density: 0.0075 | logic_density: 0.0113
#             gpt_mean: 2.8643 | gpt_var: 8.3004 | gpt_tail: 7.7891
#             gpt_d2_entropy: 1.4198 | sent_len_cv: 2.3379 | comma_density: 0.0274
#             punctuation_density: 0.1324 | pos_distribution_variance: 0.0073 | entity_grid_score: 0.0174
#             sentence_embedding_coherence: 0.7553 | embedding_distribution_entropy: 2.8953 | gpt_var_x_semantic_drift: 1.8668
#             gpt_tail_x_semantic_drift: 1.7517 | comma_density_x_gpt_var: 0.2274 | embedding_coherence_x_entropy: 2.1868
#             combo_gpt_sent_punct: 2.5697
# --------------------------------------------------------------------------------
# [ID: 64 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 68.05%
#           Snippet: Y tế từ xa (Telemedicine): Khi bác sĩ chỉ cách một nút chạm  Dịch vụ y...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0077 | additive_density: 0.0000 | logic_density: 0.0116
#             gpt_mean: 2.4089 | gpt_var: 6.1326 | gpt_tail: 6.5922
#             gpt_d2_entropy: 2.0257 | sent_len_cv: 1.1778 | comma_density: 0.0350
#             punctuation_density: 0.1050 | pos_distribution_variance: 0.0079 | entity_grid_score: 0.0272
#             sentence_embedding_coherence: 0.8082 | embedding_distribution_entropy: 2.9302 | gpt_var_x_semantic_drift: 0.8431
#             gpt_tail_x_semantic_drift: 0.9063 | comma_density_x_gpt_var: 0.2146 | embedding_coherence_x_entropy: 2.3681
#             combo_gpt_sent_punct: 0.7584
# --------------------------------------------------------------------------------
# [ID: 65 ] SAI  | Thực tế: 1   | Dự đoán: 0   | Xác suất: 36.65%
#           Snippet: Bảo tồn động vật hoang dã: Cuộc chiến chống lại sự tuyệt chủng  Tình t...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0000 | additive_density: 0.0037 | logic_density: 0.0037
#             gpt_mean: 2.5784 | gpt_var: 6.2083 | gpt_tail: 7.2119
#             gpt_d2_entropy: 1.8765 | sent_len_cv: 3.0490 | comma_density: 0.0441
#             punctuation_density: 0.1078 | pos_distribution_variance: 0.0070 | entity_grid_score: 0.0469
#             sentence_embedding_coherence: 0.7740 | embedding_distribution_entropy: 2.8685 | gpt_var_x_semantic_drift: 1.2560
#             gpt_tail_x_semantic_drift: 1.4591 | comma_density_x_gpt_var: 0.2739 | embedding_coherence_x_entropy: 2.2201
#             combo_gpt_sent_punct: 2.0414
# --------------------------------------------------------------------------------
# [ID: 66 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 53.88%
#           Snippet: Khởi nghiệp từ tài nguyên bản địa: Hướng đi mới cho thanh niên nông th...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0073 | additive_density: 0.0073 | logic_density: 0.0147
#             gpt_mean: 2.5869 | gpt_var: 6.2863 | gpt_tail: 7.7705
#             gpt_d2_entropy: 1.9703 | sent_len_cv: 2.2523 | comma_density: 0.0405
#             punctuation_density: 0.1081 | pos_distribution_variance: 0.0067 | entity_grid_score: 0.0149
#             sentence_embedding_coherence: 0.7943 | embedding_distribution_entropy: 2.8667 | gpt_var_x_semantic_drift: 0.8911
#             gpt_tail_x_semantic_drift: 1.1015 | comma_density_x_gpt_var: 0.2548 | embedding_coherence_x_entropy: 2.2772
#             combo_gpt_sent_punct: 1.5306
# --------------------------------------------------------------------------------
# [ID: 67 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 90.08%
#           Snippet: Ngành công nghiệp bán dẫn: Cuộc chơi của những gã khổng lồ và vị thế c...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0075 | additive_density: 0.0075 | logic_density: 0.0189
#             gpt_mean: 2.3671 | gpt_var: 5.2686 | gpt_tail: 6.7512
#             gpt_d2_entropy: 2.0104 | sent_len_cv: 1.5984 | comma_density: 0.0355
#             punctuation_density: 0.1015 | pos_distribution_variance: 0.0072 | entity_grid_score: 0.0341
#             sentence_embedding_coherence: 0.8097 | embedding_distribution_entropy: 2.9205 | gpt_var_x_semantic_drift: 0.9528
#             gpt_tail_x_semantic_drift: 1.2209 | comma_density_x_gpt_var: 0.1872 | embedding_coherence_x_entropy: 2.3646
#             combo_gpt_sent_punct: 0.8550
# --------------------------------------------------------------------------------
# [ID: 68 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 51.44%
#           Snippet: Hạnh phúc từ sự tối giản: Lối sống mới của cư dân đô thị  Giữa một xã ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0039 | additive_density: 0.0000 | logic_density: 0.0039
#             gpt_mean: 2.6202 | gpt_var: 6.6256 | gpt_tail: 7.4703
#             gpt_d2_entropy: 1.8454 | sent_len_cv: 2.0282 | comma_density: 0.0469
#             punctuation_density: 0.1174 | pos_distribution_variance: 0.0063 | entity_grid_score: 0.0000
#             sentence_embedding_coherence: 0.7865 | embedding_distribution_entropy: 2.9134 | gpt_var_x_semantic_drift: 1.1225
#             gpt_tail_x_semantic_drift: 1.2656 | comma_density_x_gpt_var: 0.3111 | embedding_coherence_x_entropy: 2.2913
#             combo_gpt_sent_punct: 1.5772
# --------------------------------------------------------------------------------
# [ID: 69 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 53.64%
#           Snippet: Vai trò của phụ nữ trong quản trị doanh nghiệp: Sự tinh tế tạo nên thà...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0346 | additive_density: 0.0000 | logic_density: 0.0385
#             gpt_mean: 2.3963 | gpt_var: 5.8186 | gpt_tail: 6.8945
#             gpt_d2_entropy: 2.1248 | sent_len_cv: 1.5897 | comma_density: 0.0410
#             punctuation_density: 0.1179 | pos_distribution_variance: 0.0082 | entity_grid_score: 0.0550
#             sentence_embedding_coherence: 0.7854 | embedding_distribution_entropy: 2.8266 | gpt_var_x_semantic_drift: 0.9664
#             gpt_tail_x_semantic_drift: 1.1452 | comma_density_x_gpt_var: 0.2387 | embedding_coherence_x_entropy: 2.2200
#             combo_gpt_sent_punct: 1.0910
# --------------------------------------------------------------------------------
# [ID: 70 ] SAI  | Thực tế: 1   | Dự đoán: 0   | Xác suất: 11.78%
#           Snippet: Bảo vệ dữ liệu cá nhân: Quyền riêng tư không phải là món hàng  Trong k...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0113 | additive_density: 0.0000 | logic_density: 0.0150
#             gpt_mean: 2.5382 | gpt_var: 6.9197 | gpt_tail: 7.4285
#             gpt_d2_entropy: 2.0221 | sent_len_cv: 2.0805 | comma_density: 0.0341
#             punctuation_density: 0.0927 | pos_distribution_variance: 0.0072 | entity_grid_score: 0.0365
#             sentence_embedding_coherence: 0.7113 | embedding_distribution_entropy: 2.9956 | gpt_var_x_semantic_drift: 1.1786
#             gpt_tail_x_semantic_drift: 1.2653 | comma_density_x_gpt_var: 0.2363 | embedding_coherence_x_entropy: 2.1309
#             combo_gpt_sent_punct: 1.3343
# --------------------------------------------------------------------------------
# [ID: 71 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 88.69%
#           Snippet: Sự phát triển của xe đạp đô thị: Tìm lại thói quen xanh cho thành phố ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0071 | additive_density: 0.0071 | logic_density: 0.0178
#             gpt_mean: 2.2456 | gpt_var: 5.2490 | gpt_tail: 6.4910
#             gpt_d2_entropy: 1.8436 | sent_len_cv: 2.2236 | comma_density: 0.0360
#             punctuation_density: 0.1081 | pos_distribution_variance: 0.0083 | entity_grid_score: 0.0344
#             sentence_embedding_coherence: 0.7681 | embedding_distribution_entropy: 3.1504 | gpt_var_x_semantic_drift: 1.2999
#             gpt_tail_x_semantic_drift: 1.6075 | comma_density_x_gpt_var: 0.1892 | embedding_coherence_x_entropy: 2.4199
#             combo_gpt_sent_punct: 1.2618
# --------------------------------------------------------------------------------
# [ID: 72 ] SAI  | Thực tế: 1   | Dự đoán: 0   | Xác suất: 42.75%
#           Snippet: Nghệ thuật đường phố (Street Art): Từ 'vẽ bậy' đến bản sắc đô thị  Từn...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0077 | additive_density: 0.0038 | logic_density: 0.0115
#             gpt_mean: 2.4847 | gpt_var: 6.8564 | gpt_tail: 7.4043
#             gpt_d2_entropy: 1.9422 | sent_len_cv: 2.6486 | comma_density: 0.0478
#             punctuation_density: 0.1244 | pos_distribution_variance: 0.0074 | entity_grid_score: 0.0379
#             sentence_embedding_coherence: 0.7769 | embedding_distribution_entropy: 2.8961 | gpt_var_x_semantic_drift: 1.0458
#             gpt_tail_x_semantic_drift: 1.1293 | comma_density_x_gpt_var: 0.3281 | embedding_coherence_x_entropy: 2.2500
#             combo_gpt_sent_punct: 2.2591
# --------------------------------------------------------------------------------
# [ID: 73 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 57.31%
#           Snippet: Lớp học đảo ngược (Flipped Classroom): Cuộc cách mạng trong phương phá...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0038 | additive_density: 0.0000 | logic_density: 0.0075
#             gpt_mean: 2.3062 | gpt_var: 5.3640 | gpt_tail: 7.1074
#             gpt_d2_entropy: 2.1086 | sent_len_cv: 1.0796 | comma_density: 0.0243
#             punctuation_density: 0.1117 | pos_distribution_variance: 0.0086 | entity_grid_score: 0.0514
#             sentence_embedding_coherence: 0.8078 | embedding_distribution_entropy: 3.0694 | gpt_var_x_semantic_drift: 0.8660
#             gpt_tail_x_semantic_drift: 1.1474 | comma_density_x_gpt_var: 0.1302 | embedding_coherence_x_entropy: 2.4794
#             combo_gpt_sent_punct: 0.6466
# --------------------------------------------------------------------------------
# [ID: 74 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 50.08%
#           Snippet: Công nghệ in 3D trong y học: Từ mô hình đến các bộ phận cơ thể người  ...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0000 | additive_density: 0.0073 | logic_density: 0.0110
#             gpt_mean: 2.4212 | gpt_var: 5.6034 | gpt_tail: 7.0557
#             gpt_d2_entropy: 1.9583 | sent_len_cv: 2.2963 | comma_density: 0.0278
#             punctuation_density: 0.0926 | pos_distribution_variance: 0.0090 | entity_grid_score: 0.0175
#             sentence_embedding_coherence: 0.7633 | embedding_distribution_entropy: 2.5258 | gpt_var_x_semantic_drift: 0.5684
#             gpt_tail_x_semantic_drift: 0.7158 | comma_density_x_gpt_var: 0.1556 | embedding_coherence_x_entropy: 1.9280
#             combo_gpt_sent_punct: 1.1914
# --------------------------------------------------------------------------------
# [ID: 75 ] SAI  | Thực tế: 1   | Dự đoán: 0   | Xác suất: 2.52%
#           Snippet: Thử thách cân bằng cuộc sống và công việc (Work-Life Balance) trong th...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0081 | additive_density: 0.0000 | logic_density: 0.0162
#             gpt_mean: 2.7397 | gpt_var: 7.0735 | gpt_tail: 7.9717
#             gpt_d2_entropy: 1.9895 | sent_len_cv: 1.3731 | comma_density: 0.0211
#             punctuation_density: 0.1368 | pos_distribution_variance: 0.0069 | entity_grid_score: 0.0621
#             sentence_embedding_coherence: 0.7765 | embedding_distribution_entropy: 2.8821 | gpt_var_x_semantic_drift: 1.8432
#             gpt_tail_x_semantic_drift: 2.0773 | comma_density_x_gpt_var: 0.1489 | embedding_coherence_x_entropy: 2.2379
#             combo_gpt_sent_punct: 1.3291
# --------------------------------------------------------------------------------
# [ID: 76 ] ĐÚNG | Thực tế: 1   | Dự đoán: 1   | Xác suất: 80.65%
#           Snippet: Trí tuệ nhân tạo (AI) trong nghệ thuật: Sáng tạo hay sao chép?  Việc x...
#           [Chi tiết Đặc Trưng]:
#             causal_density: 0.0073 | additive_density: 0.0036 | logic_density: 0.0182
#             gpt_mean: 2.5520 | gpt_var: 5.2957 | gpt_tail: 6.9092
#             gpt_d2_entropy: 1.9301 | sent_len_cv: 1.4307 | comma_density: 0.0349
#             punctuation_density: 0.1179 | pos_distribution_variance: 0.0051 | entity_grid_score: 0.0254
#             sentence_embedding_coherence: 0.7819 | embedding_distribution_entropy: 3.2054 | gpt_var_x_semantic_drift: 1.4332
#             gpt_tail_x_semantic_drift: 1.8698 | comma_density_x_gpt_var: 0.1850 | embedding_coherence_x_entropy: 2.5061
#             combo_gpt_sent_punct: 0.8933
# --------------------------------------------------------------------------------
# Đã xuất báo cáo ra file: Model/Reports/xgboost_evaluation_report.xlsx
